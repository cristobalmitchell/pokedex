# %% [markdown]
# # Pokedex
# This notebook is used to collect the full pokedex dataset from Gen IX
# Based on original notebook from https://github.com/cristobalmitchell/pokedex

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# We will use bulbapedia.bulbagarden.net to collect the name of all the pokemon.

# %%
url = "https://bulbapedia.bulbagarden.net/wiki/List_of_Pokémon_by_National_Pokédex_number"

# %%
r = requests.get(url)
soup = BeautifulSoup(r.text, "html.parser")
rows = soup.find_all("tr")

print(len(rows))
# Out:
# 1212

# %%
df = pd.DataFrame()
for row in rows:
    if len(row.find_all("th")) > 1:
        headers = [header.text.replace('\n','').replace(' ','') for header in row.find_all("th")]
    elif len(row.find_all("td")) > 1: 
        record = {}
        for i in range(len(row.find_all("td"))):
            if i < len(headers):
                record[headers[i]] = row.find_all("td")[i].text.replace('\n','').replace(' ','')
        df = pd.concat([df, pd.DataFrame([record])], ignore_index=True)

print(df.head())
# Out:
#     Ndex MS     Pokémon   Type
# 0  #0001      Bulbasaur  Grass
# 1  #0002        Ivysaur  Grass
# 2  #0003       Venusaur  Grass
# 3  #0004     Charmander   Fire
# 4  #0005     Charmeleon   Fire

# %%
cols = ['Ndex', 'Pokémon']
df = df[cols]
df.drop_duplicates(inplace=True)
print(df.head())

df = df[df['Ndex'].notnull() & (df['Ndex'] != '')]
df = df.reset_index(drop=True)
print(f"Number of rows: {len(df)}")
# Out:
#     Ndex     Pokémon
# 0  #0001   Bulbasaur
# 1  #0002     Ivysaur
# 2  #0003    Venusaur
# 3  #0004  Charmander
# 4  #0005  Charmeleon
# Number of rows: 1025

# %%
for index, name in df['Pokémon'].items():
    print(f"index: {index+1}, real national number: {df.loc[index, 'Ndex']}, name: {name}")
# Out:
# index: 1, real national number: #0001, name: Bulbasaur
# index: 2, real national number: #0002, name: Ivysaur
# index: 3, real national number: #0003, name: Venusaur
# index: 4, real national number: #0004, name: Charmander
# index: 5, real national number: #0005, name: Charmeleon
# index: 6, real national number: #0006, name: Charizard
# index: 7, real national number: #0007, name: Squirtle
# index: 8, real national number: #0008, name: Wartortle
# index: 9, real national number: #0009, name: Blastoise
# index: 10, real national number: #0010, name: Caterpie
# index: 11, real national number: #0011, name: Metapod
# index: 12, real national number: #0012, name: Butterfree
# index: 13, real national number: #0013, name: Weedle
# index: 14, real national number: #0014, name: Kakuna
# index: 15, real national number: #0015, name: Beedrill
# index: 16, real national number: #0016, name: Pidgey
# index: 17, real national number: #0017, name: Pidgeotto
# index: 18, real national number: #0018, name: Pidgeot
# index: 19, real national number: #0019, name: Rattata
# index: 20, real national number: #0020, name: Raticate
# index: 21, real national number: #0021, name: Spearow
# index: 22, real national number: #0022, name: Fearow
# index: 23, real national number: #0023, name: Ekans
# index: 24, real national number: #0024, name: Arbok
# index: 25, real national number: #0025, name: Pikachu
# index: 26, real national number: #0026, name: Raichu
# index: 27, real national number: #0027, name: Sandshrew
# index: 28, real national number: #0028, name: Sandslash
# index: 29, real national number: #0029, name: Nidoran♀
# index: 30, real national number: #0030, name: Nidorina
# index: 31, real national number: #0031, name: Nidoqueen
# index: 32, real national number: #0032, name: Nidoran♂
# index: 33, real national number: #0033, name: Nidorino
# index: 34, real national number: #0034, name: Nidoking
# index: 35, real national number: #0035, name: Clefairy
# index: 36, real national number: #0036, name: Clefable
# index: 37, real national number: #0037, name: Vulpix
# index: 38, real national number: #0038, name: Ninetales
# index: 39, real national number: #0039, name: Jigglypuff
# index: 40, real national number: #0040, name: Wigglytuff
# index: 41, real national number: #0041, name: Zubat
# index: 42, real national number: #0042, name: Golbat
# index: 43, real national number: #0043, name: Oddish
# index: 44, real national number: #0044, name: Gloom
# index: 45, real national number: #0045, name: Vileplume
# index: 46, real national number: #0046, name: Paras
# index: 47, real national number: #0047, name: Parasect
# index: 48, real national number: #0048, name: Venonat
# index: 49, real national number: #0049, name: Venomoth
# index: 50, real national number: #0050, name: Diglett
# index: 51, real national number: #0051, name: Dugtrio
# index: 52, real national number: #0052, name: Meowth
# index: 53, real national number: #0053, name: Persian
# index: 54, real national number: #0054, name: Psyduck
# index: 55, real national number: #0055, name: Golduck
# index: 56, real national number: #0056, name: Mankey
# index: 57, real national number: #0057, name: Primeape
# index: 58, real national number: #0058, name: Growlithe
# index: 59, real national number: #0059, name: Arcanine
# index: 60, real national number: #0060, name: Poliwag
# index: 61, real national number: #0061, name: Poliwhirl
# index: 62, real national number: #0062, name: Poliwrath
# index: 63, real national number: #0063, name: Abra
# index: 64, real national number: #0064, name: Kadabra
# index: 65, real national number: #0065, name: Alakazam
# index: 66, real national number: #0066, name: Machop
# index: 67, real national number: #0067, name: Machoke
# index: 68, real national number: #0068, name: Machamp
# index: 69, real national number: #0069, name: Bellsprout
# index: 70, real national number: #0070, name: Weepinbell
# index: 71, real national number: #0071, name: Victreebel
# index: 72, real national number: #0072, name: Tentacool
# index: 73, real national number: #0073, name: Tentacruel
# index: 74, real national number: #0074, name: Geodude
# index: 75, real national number: #0075, name: Graveler
# index: 76, real national number: #0076, name: Golem
# index: 77, real national number: #0077, name: Ponyta
# index: 78, real national number: #0078, name: Rapidash
# index: 79, real national number: #0079, name: Slowpoke
# index: 80, real national number: #0080, name: Slowbro
# index: 81, real national number: #0081, name: Magnemite
# index: 82, real national number: #0082, name: Magneton
# index: 83, real national number: #0083, name: Farfetch'd
# index: 84, real national number: #0084, name: Doduo
# index: 85, real national number: #0085, name: Dodrio
# index: 86, real national number: #0086, name: Seel
# index: 87, real national number: #0087, name: Dewgong
# index: 88, real national number: #0088, name: Grimer
# index: 89, real national number: #0089, name: Muk
# index: 90, real national number: #0090, name: Shellder
# index: 91, real national number: #0091, name: Cloyster
# index: 92, real national number: #0092, name: Gastly
# index: 93, real national number: #0093, name: Haunter
# index: 94, real national number: #0094, name: Gengar
# index: 95, real national number: #0095, name: Onix
# index: 96, real national number: #0096, name: Drowzee
# index: 97, real national number: #0097, name: Hypno
# index: 98, real national number: #0098, name: Krabby
# index: 99, real national number: #0099, name: Kingler
# index: 100, real national number: #0100, name: Voltorb
# index: 101, real national number: #0101, name: Electrode
# index: 102, real national number: #0102, name: Exeggcute
# index: 103, real national number: #0103, name: Exeggutor
# index: 104, real national number: #0104, name: Cubone
# index: 105, real national number: #0105, name: Marowak
# index: 106, real national number: #0106, name: Hitmonlee
# index: 107, real national number: #0107, name: Hitmonchan
# index: 108, real national number: #0108, name: Lickitung
# index: 109, real national number: #0109, name: Koffing
# index: 110, real national number: #0110, name: Weezing
# index: 111, real national number: #0111, name: Rhyhorn
# index: 112, real national number: #0112, name: Rhydon
# index: 113, real national number: #0113, name: Chansey
# index: 114, real national number: #0114, name: Tangela
# index: 115, real national number: #0115, name: Kangaskhan
# index: 116, real national number: #0116, name: Horsea
# index: 117, real national number: #0117, name: Seadra
# index: 118, real national number: #0118, name: Goldeen
# index: 119, real national number: #0119, name: Seaking
# index: 120, real national number: #0120, name: Staryu
# index: 121, real national number: #0121, name: Starmie
# index: 122, real national number: #0122, name: Mr.Mime
# index: 123, real national number: #0123, name: Scyther
# index: 124, real national number: #0124, name: Jynx
# index: 125, real national number: #0125, name: Electabuzz
# index: 126, real national number: #0126, name: Magmar
# index: 127, real national number: #0127, name: Pinsir
# index: 128, real national number: #0128, name: Tauros
# index: 129, real national number: #0129, name: Magikarp
# index: 130, real national number: #0130, name: Gyarados
# index: 131, real national number: #0131, name: Lapras
# index: 132, real national number: #0132, name: Ditto
# index: 133, real national number: #0133, name: Eevee
# index: 134, real national number: #0134, name: Vaporeon
# index: 135, real national number: #0135, name: Jolteon
# index: 136, real national number: #0136, name: Flareon
# index: 137, real national number: #0137, name: Porygon
# index: 138, real national number: #0138, name: Omanyte
# index: 139, real national number: #0139, name: Omastar
# index: 140, real national number: #0140, name: Kabuto
# index: 141, real national number: #0141, name: Kabutops
# index: 142, real national number: #0142, name: Aerodactyl
# index: 143, real national number: #0143, name: Snorlax
# index: 144, real national number: #0144, name: Articuno
# index: 145, real national number: #0145, name: Zapdos
# index: 146, real national number: #0146, name: Moltres
# index: 147, real national number: #0147, name: Dratini
# index: 148, real national number: #0148, name: Dragonair
# index: 149, real national number: #0149, name: Dragonite
# index: 150, real national number: #0150, name: Mewtwo
# index: 151, real national number: #0151, name: Mew
# index: 152, real national number: #0152, name: Chikorita
# index: 153, real national number: #0153, name: Bayleef
# index: 154, real national number: #0154, name: Meganium
# index: 155, real national number: #0155, name: Cyndaquil
# index: 156, real national number: #0156, name: Quilava
# index: 157, real national number: #0157, name: Typhlosion
# index: 158, real national number: #0158, name: Totodile
# index: 159, real national number: #0159, name: Croconaw
# index: 160, real national number: #0160, name: Feraligatr
# index: 161, real national number: #0161, name: Sentret
# index: 162, real national number: #0162, name: Furret
# index: 163, real national number: #0163, name: Hoothoot
# index: 164, real national number: #0164, name: Noctowl
# index: 165, real national number: #0165, name: Ledyba
# index: 166, real national number: #0166, name: Ledian
# index: 167, real national number: #0167, name: Spinarak
# index: 168, real national number: #0168, name: Ariados
# index: 169, real national number: #0169, name: Crobat
# index: 170, real national number: #0170, name: Chinchou
# index: 171, real national number: #0171, name: Lanturn
# index: 172, real national number: #0172, name: Pichu
# index: 173, real national number: #0173, name: Cleffa
# index: 174, real national number: #0174, name: Igglybuff
# index: 175, real national number: #0175, name: Togepi
# index: 176, real national number: #0176, name: Togetic
# index: 177, real national number: #0177, name: Natu
# index: 178, real national number: #0178, name: Xatu
# index: 179, real national number: #0179, name: Mareep
# index: 180, real national number: #0180, name: Flaaffy
# index: 181, real national number: #0181, name: Ampharos
# index: 182, real national number: #0182, name: Bellossom
# index: 183, real national number: #0183, name: Marill
# index: 184, real national number: #0184, name: Azumarill
# index: 185, real national number: #0185, name: Sudowoodo
# index: 186, real national number: #0186, name: Politoed
# index: 187, real national number: #0187, name: Hoppip
# index: 188, real national number: #0188, name: Skiploom
# index: 189, real national number: #0189, name: Jumpluff
# index: 190, real national number: #0190, name: Aipom
# index: 191, real national number: #0191, name: Sunkern
# index: 192, real national number: #0192, name: Sunflora
# index: 193, real national number: #0193, name: Yanma
# index: 194, real national number: #0194, name: Wooper
# index: 195, real national number: #0195, name: Quagsire
# index: 196, real national number: #0196, name: Espeon
# index: 197, real national number: #0197, name: Umbreon
# index: 198, real national number: #0198, name: Murkrow
# index: 199, real national number: #0199, name: Slowking
# index: 200, real national number: #0200, name: Misdreavus
# index: 201, real national number: #0201, name: UnownOneform
# index: 202, real national number: #0202, name: Wobbuffet
# index: 203, real national number: #0203, name: Girafarig
# index: 204, real national number: #0204, name: Pineco
# index: 205, real national number: #0205, name: Forretress
# index: 206, real national number: #0206, name: Dunsparce
# index: 207, real national number: #0207, name: Gligar
# index: 208, real national number: #0208, name: Steelix
# index: 209, real national number: #0209, name: Snubbull
# index: 210, real national number: #0210, name: Granbull
# index: 211, real national number: #0211, name: Qwilfish
# index: 212, real national number: #0212, name: Scizor
# index: 213, real national number: #0213, name: Shuckle
# index: 214, real national number: #0214, name: Heracross
# index: 215, real national number: #0215, name: Sneasel
# index: 216, real national number: #0216, name: Teddiursa
# index: 217, real national number: #0217, name: Ursaring
# index: 218, real national number: #0218, name: Slugma
# index: 219, real national number: #0219, name: Magcargo
# index: 220, real national number: #0220, name: Swinub
# index: 221, real national number: #0221, name: Piloswine
# index: 222, real national number: #0222, name: Corsola
# index: 223, real national number: #0223, name: Remoraid
# index: 224, real national number: #0224, name: Octillery
# index: 225, real national number: #0225, name: Delibird
# index: 226, real national number: #0226, name: Mantine
# index: 227, real national number: #0227, name: Skarmory
# index: 228, real national number: #0228, name: Houndour
# index: 229, real national number: #0229, name: Houndoom
# index: 230, real national number: #0230, name: Kingdra
# index: 231, real national number: #0231, name: Phanpy
# index: 232, real national number: #0232, name: Donphan
# index: 233, real national number: #0233, name: Porygon2
# index: 234, real national number: #0234, name: Stantler
# index: 235, real national number: #0235, name: Smeargle
# index: 236, real national number: #0236, name: Tyrogue
# index: 237, real national number: #0237, name: Hitmontop
# index: 238, real national number: #0238, name: Smoochum
# index: 239, real national number: #0239, name: Elekid
# index: 240, real national number: #0240, name: Magby
# index: 241, real national number: #0241, name: Miltank
# index: 242, real national number: #0242, name: Blissey
# index: 243, real national number: #0243, name: Raikou
# index: 244, real national number: #0244, name: Entei
# index: 245, real national number: #0245, name: Suicune
# index: 246, real national number: #0246, name: Larvitar
# index: 247, real national number: #0247, name: Pupitar
# index: 248, real national number: #0248, name: Tyranitar
# index: 249, real national number: #0249, name: Lugia
# index: 250, real national number: #0250, name: Ho-Oh
# index: 251, real national number: #0251, name: Celebi
# index: 252, real national number: #0252, name: Treecko
# index: 253, real national number: #0253, name: Grovyle
# index: 254, real national number: #0254, name: Sceptile
# index: 255, real national number: #0255, name: Torchic
# index: 256, real national number: #0256, name: Combusken
# index: 257, real national number: #0257, name: Blaziken
# index: 258, real national number: #0258, name: Mudkip
# index: 259, real national number: #0259, name: Marshtomp
# index: 260, real national number: #0260, name: Swampert
# index: 261, real national number: #0261, name: Poochyena
# index: 262, real national number: #0262, name: Mightyena
# index: 263, real national number: #0263, name: Zigzagoon
# index: 264, real national number: #0264, name: Linoone
# index: 265, real national number: #0265, name: Wurmple
# index: 266, real national number: #0266, name: Silcoon
# index: 267, real national number: #0267, name: Beautifly
# index: 268, real national number: #0268, name: Cascoon
# index: 269, real national number: #0269, name: Dustox
# index: 270, real national number: #0270, name: Lotad
# index: 271, real national number: #0271, name: Lombre
# index: 272, real national number: #0272, name: Ludicolo
# index: 273, real national number: #0273, name: Seedot
# index: 274, real national number: #0274, name: Nuzleaf
# index: 275, real national number: #0275, name: Shiftry
# index: 276, real national number: #0276, name: Taillow
# index: 277, real national number: #0277, name: Swellow
# index: 278, real national number: #0278, name: Wingull
# index: 279, real national number: #0279, name: Pelipper
# index: 280, real national number: #0280, name: Ralts
# index: 281, real national number: #0281, name: Kirlia
# index: 282, real national number: #0282, name: Gardevoir
# index: 283, real national number: #0283, name: Surskit
# index: 284, real national number: #0284, name: Masquerain
# index: 285, real national number: #0285, name: Shroomish
# index: 286, real national number: #0286, name: Breloom
# index: 287, real national number: #0287, name: Slakoth
# index: 288, real national number: #0288, name: Vigoroth
# index: 289, real national number: #0289, name: Slaking
# index: 290, real national number: #0290, name: Nincada
# index: 291, real national number: #0291, name: Ninjask
# index: 292, real national number: #0292, name: Shedinja
# index: 293, real national number: #0293, name: Whismur
# index: 294, real national number: #0294, name: Loudred
# index: 295, real national number: #0295, name: Exploud
# index: 296, real national number: #0296, name: Makuhita
# index: 297, real national number: #0297, name: Hariyama
# index: 298, real national number: #0298, name: Azurill
# index: 299, real national number: #0299, name: Nosepass
# index: 300, real national number: #0300, name: Skitty
# index: 301, real national number: #0301, name: Delcatty
# index: 302, real national number: #0302, name: Sableye
# index: 303, real national number: #0303, name: Mawile
# index: 304, real national number: #0304, name: Aron
# index: 305, real national number: #0305, name: Lairon
# index: 306, real national number: #0306, name: Aggron
# index: 307, real national number: #0307, name: Meditite
# index: 308, real national number: #0308, name: Medicham
# index: 309, real national number: #0309, name: Electrike
# index: 310, real national number: #0310, name: Manectric
# index: 311, real national number: #0311, name: Plusle
# index: 312, real national number: #0312, name: Minun
# index: 313, real national number: #0313, name: Volbeat
# index: 314, real national number: #0314, name: Illumise
# index: 315, real national number: #0315, name: Roselia
# index: 316, real national number: #0316, name: Gulpin
# index: 317, real national number: #0317, name: Swalot
# index: 318, real national number: #0318, name: Carvanha
# index: 319, real national number: #0319, name: Sharpedo
# index: 320, real national number: #0320, name: Wailmer
# index: 321, real national number: #0321, name: Wailord
# index: 322, real national number: #0322, name: Numel
# index: 323, real national number: #0323, name: Camerupt
# index: 324, real national number: #0324, name: Torkoal
# index: 325, real national number: #0325, name: Spoink
# index: 326, real national number: #0326, name: Grumpig
# index: 327, real national number: #0327, name: Spinda
# index: 328, real national number: #0328, name: Trapinch
# index: 329, real national number: #0329, name: Vibrava
# index: 330, real national number: #0330, name: Flygon
# index: 331, real national number: #0331, name: Cacnea
# index: 332, real national number: #0332, name: Cacturne
# index: 333, real national number: #0333, name: Swablu
# index: 334, real national number: #0334, name: Altaria
# index: 335, real national number: #0335, name: Zangoose
# index: 336, real national number: #0336, name: Seviper
# index: 337, real national number: #0337, name: Lunatone
# index: 338, real national number: #0338, name: Solrock
# index: 339, real national number: #0339, name: Barboach
# index: 340, real national number: #0340, name: Whiscash
# index: 341, real national number: #0341, name: Corphish
# index: 342, real national number: #0342, name: Crawdaunt
# index: 343, real national number: #0343, name: Baltoy
# index: 344, real national number: #0344, name: Claydol
# index: 345, real national number: #0345, name: Lileep
# index: 346, real national number: #0346, name: Cradily
# index: 347, real national number: #0347, name: Anorith
# index: 348, real national number: #0348, name: Armaldo
# index: 349, real national number: #0349, name: Feebas
# index: 350, real national number: #0350, name: Milotic
# index: 351, real national number: #0351, name: CastformNormal
# index: 352, real national number: #0352, name: Kecleon
# index: 353, real national number: #0353, name: Shuppet
# index: 354, real national number: #0354, name: Banette
# index: 355, real national number: #0355, name: Duskull
# index: 356, real national number: #0356, name: Dusclops
# index: 357, real national number: #0357, name: Tropius
# index: 358, real national number: #0358, name: Chimecho
# index: 359, real national number: #0359, name: Absol
# index: 360, real national number: #0360, name: Wynaut
# index: 361, real national number: #0361, name: Snorunt
# index: 362, real national number: #0362, name: Glalie
# index: 363, real national number: #0363, name: Spheal
# index: 364, real national number: #0364, name: Sealeo
# index: 365, real national number: #0365, name: Walrein
# index: 366, real national number: #0366, name: Clamperl
# index: 367, real national number: #0367, name: Huntail
# index: 368, real national number: #0368, name: Gorebyss
# index: 369, real national number: #0369, name: Relicanth
# index: 370, real national number: #0370, name: Luvdisc
# index: 371, real national number: #0371, name: Bagon
# index: 372, real national number: #0372, name: Shelgon
# index: 373, real national number: #0373, name: Salamence
# index: 374, real national number: #0374, name: Beldum
# index: 375, real national number: #0375, name: Metang
# index: 376, real national number: #0376, name: Metagross
# index: 377, real national number: #0377, name: Regirock
# index: 378, real national number: #0378, name: Regice
# index: 379, real national number: #0379, name: Registeel
# index: 380, real national number: #0380, name: Latias
# index: 381, real national number: #0381, name: Latios
# index: 382, real national number: #0382, name: KyogreKyogre
# index: 383, real national number: #0383, name: GroudonGroudon
# index: 384, real national number: #0384, name: Rayquaza
# index: 385, real national number: #0385, name: Jirachi
# index: 386, real national number: #0386, name: DeoxysNormalForme
# index: 387, real national number: #0387, name: Turtwig
# index: 388, real national number: #0388, name: Grotle
# index: 389, real national number: #0389, name: Torterra
# index: 390, real national number: #0390, name: Chimchar
# index: 391, real national number: #0391, name: Monferno
# index: 392, real national number: #0392, name: Infernape
# index: 393, real national number: #0393, name: Piplup
# index: 394, real national number: #0394, name: Prinplup
# index: 395, real national number: #0395, name: Empoleon
# index: 396, real national number: #0396, name: Starly
# index: 397, real national number: #0397, name: Staravia
# index: 398, real national number: #0398, name: Staraptor
# index: 399, real national number: #0399, name: Bidoof
# index: 400, real national number: #0400, name: Bibarel
# index: 401, real national number: #0401, name: Kricketot
# index: 402, real national number: #0402, name: Kricketune
# index: 403, real national number: #0403, name: Shinx
# index: 404, real national number: #0404, name: Luxio
# index: 405, real national number: #0405, name: Luxray
# index: 406, real national number: #0406, name: Budew
# index: 407, real national number: #0407, name: Roserade
# index: 408, real national number: #0408, name: Cranidos
# index: 409, real national number: #0409, name: Rampardos
# index: 410, real national number: #0410, name: Shieldon
# index: 411, real national number: #0411, name: Bastiodon
# index: 412, real national number: #0412, name: BurmyPlantCloak
# index: 413, real national number: #0413, name: WormadamPlantCloak
# index: 414, real national number: #0414, name: Mothim
# index: 415, real national number: #0415, name: Combee
# index: 416, real national number: #0416, name: Vespiquen
# index: 417, real national number: #0417, name: Pachirisu
# index: 418, real national number: #0418, name: Buizel
# index: 419, real national number: #0419, name: Floatzel
# index: 420, real national number: #0420, name: Cherubi
# index: 421, real national number: #0421, name: CherrimOvercastForm
# index: 422, real national number: #0422, name: ShellosWestSea
# index: 423, real national number: #0423, name: GastrodonWestSea
# index: 424, real national number: #0424, name: Ambipom
# index: 425, real national number: #0425, name: Drifloon
# index: 426, real national number: #0426, name: Drifblim
# index: 427, real national number: #0427, name: Buneary
# index: 428, real national number: #0428, name: Lopunny
# index: 429, real national number: #0429, name: Mismagius
# index: 430, real national number: #0430, name: Honchkrow
# index: 431, real national number: #0431, name: Glameow
# index: 432, real national number: #0432, name: Purugly
# index: 433, real national number: #0433, name: Chingling
# index: 434, real national number: #0434, name: Stunky
# index: 435, real national number: #0435, name: Skuntank
# index: 436, real national number: #0436, name: Bronzor
# index: 437, real national number: #0437, name: Bronzong
# index: 438, real national number: #0438, name: Bonsly
# index: 439, real national number: #0439, name: MimeJr.
# index: 440, real national number: #0440, name: Happiny
# index: 441, real national number: #0441, name: Chatot
# index: 442, real national number: #0442, name: Spiritomb
# index: 443, real national number: #0443, name: Gible
# index: 444, real national number: #0444, name: Gabite
# index: 445, real national number: #0445, name: Garchomp
# index: 446, real national number: #0446, name: Munchlax
# index: 447, real national number: #0447, name: Riolu
# index: 448, real national number: #0448, name: Lucario
# index: 449, real national number: #0449, name: Hippopotas
# index: 450, real national number: #0450, name: Hippowdon
# index: 451, real national number: #0451, name: Skorupi
# index: 452, real national number: #0452, name: Drapion
# index: 453, real national number: #0453, name: Croagunk
# index: 454, real national number: #0454, name: Toxicroak
# index: 455, real national number: #0455, name: Carnivine
# index: 456, real national number: #0456, name: Finneon
# index: 457, real national number: #0457, name: Lumineon
# index: 458, real national number: #0458, name: Mantyke
# index: 459, real national number: #0459, name: Snover
# index: 460, real national number: #0460, name: Abomasnow
# index: 461, real national number: #0461, name: Weavile
# index: 462, real national number: #0462, name: Magnezone
# index: 463, real national number: #0463, name: Lickilicky
# index: 464, real national number: #0464, name: Rhyperior
# index: 465, real national number: #0465, name: Tangrowth
# index: 466, real national number: #0466, name: Electivire
# index: 467, real national number: #0467, name: Magmortar
# index: 468, real national number: #0468, name: Togekiss
# index: 469, real national number: #0469, name: Yanmega
# index: 470, real national number: #0470, name: Leafeon
# index: 471, real national number: #0471, name: Glaceon
# index: 472, real national number: #0472, name: Gliscor
# index: 473, real national number: #0473, name: Mamoswine
# index: 474, real national number: #0474, name: Porygon-Z
# index: 475, real national number: #0475, name: Gallade
# index: 476, real national number: #0476, name: Probopass
# index: 477, real national number: #0477, name: Dusknoir
# index: 478, real national number: #0478, name: Froslass
# index: 479, real national number: #0479, name: RotomRotom
# index: 480, real national number: #0480, name: Uxie
# index: 481, real national number: #0481, name: Mesprit
# index: 482, real national number: #0482, name: Azelf
# index: 483, real national number: #0483, name: Dialga
# index: 484, real national number: #0484, name: Palkia
# index: 485, real national number: #0485, name: Heatran
# index: 486, real national number: #0486, name: Regigigas
# index: 487, real national number: #0487, name: GiratinaAlteredForme
# index: 488, real national number: #0488, name: Cresselia
# index: 489, real national number: #0489, name: Phione
# index: 490, real national number: #0490, name: Manaphy
# index: 491, real national number: #0491, name: Darkrai
# index: 492, real national number: #0492, name: ShayminLandForme
# index: 493, real national number: #0493, name: ArceusArceus
# index: 494, real national number: #0494, name: Victini
# index: 495, real national number: #0495, name: Snivy
# index: 496, real national number: #0496, name: Servine
# index: 497, real national number: #0497, name: Serperior
# index: 498, real national number: #0498, name: Tepig
# index: 499, real national number: #0499, name: Pignite
# index: 500, real national number: #0500, name: Emboar
# index: 501, real national number: #0501, name: Oshawott
# index: 502, real national number: #0502, name: Dewott
# index: 503, real national number: #0503, name: Samurott
# index: 504, real national number: #0504, name: Patrat
# index: 505, real national number: #0505, name: Watchog
# index: 506, real national number: #0506, name: Lillipup
# index: 507, real national number: #0507, name: Herdier
# index: 508, real national number: #0508, name: Stoutland
# index: 509, real national number: #0509, name: Purrloin
# index: 510, real national number: #0510, name: Liepard
# index: 511, real national number: #0511, name: Pansage
# index: 512, real national number: #0512, name: Simisage
# index: 513, real national number: #0513, name: Pansear
# index: 514, real national number: #0514, name: Simisear
# index: 515, real national number: #0515, name: Panpour
# index: 516, real national number: #0516, name: Simipour
# index: 517, real national number: #0517, name: Munna
# index: 518, real national number: #0518, name: Musharna
# index: 519, real national number: #0519, name: Pidove
# index: 520, real national number: #0520, name: Tranquill
# index: 521, real national number: #0521, name: Unfezant
# index: 522, real national number: #0522, name: Blitzle
# index: 523, real national number: #0523, name: Zebstrika
# index: 524, real national number: #0524, name: Roggenrola
# index: 525, real national number: #0525, name: Boldore
# index: 526, real national number: #0526, name: Gigalith
# index: 527, real national number: #0527, name: Woobat
# index: 528, real national number: #0528, name: Swoobat
# index: 529, real national number: #0529, name: Drilbur
# index: 530, real national number: #0530, name: Excadrill
# index: 531, real national number: #0531, name: Audino
# index: 532, real national number: #0532, name: Timburr
# index: 533, real national number: #0533, name: Gurdurr
# index: 534, real national number: #0534, name: Conkeldurr
# index: 535, real national number: #0535, name: Tympole
# index: 536, real national number: #0536, name: Palpitoad
# index: 537, real national number: #0537, name: Seismitoad
# index: 538, real national number: #0538, name: Throh
# index: 539, real national number: #0539, name: Sawk
# index: 540, real national number: #0540, name: Sewaddle
# index: 541, real national number: #0541, name: Swadloon
# index: 542, real national number: #0542, name: Leavanny
# index: 543, real national number: #0543, name: Venipede
# index: 544, real national number: #0544, name: Whirlipede
# index: 545, real national number: #0545, name: Scolipede
# index: 546, real national number: #0546, name: Cottonee
# index: 547, real national number: #0547, name: Whimsicott
# index: 548, real national number: #0548, name: Petilil
# index: 549, real national number: #0549, name: Lilligant
# index: 550, real national number: #0550, name: BasculinRed-StripedForm
# index: 551, real national number: #0551, name: Sandile
# index: 552, real national number: #0552, name: Krokorok
# index: 553, real national number: #0553, name: Krookodile
# index: 554, real national number: #0554, name: Darumaka
# index: 555, real national number: #0555, name: DarmanitanStandardMode
# index: 556, real national number: #0556, name: Maractus
# index: 557, real national number: #0557, name: Dwebble
# index: 558, real national number: #0558, name: Crustle
# index: 559, real national number: #0559, name: Scraggy
# index: 560, real national number: #0560, name: Scrafty
# index: 561, real national number: #0561, name: Sigilyph
# index: 562, real national number: #0562, name: Yamask
# index: 563, real national number: #0563, name: Cofagrigus
# index: 564, real national number: #0564, name: Tirtouga
# index: 565, real national number: #0565, name: Carracosta
# index: 566, real national number: #0566, name: Archen
# index: 567, real national number: #0567, name: Archeops
# index: 568, real national number: #0568, name: Trubbish
# index: 569, real national number: #0569, name: Garbodor
# index: 570, real national number: #0570, name: Zorua
# index: 571, real national number: #0571, name: Zoroark
# index: 572, real national number: #0572, name: Minccino
# index: 573, real national number: #0573, name: Cinccino
# index: 574, real national number: #0574, name: Gothita
# index: 575, real national number: #0575, name: Gothorita
# index: 576, real national number: #0576, name: Gothitelle
# index: 577, real national number: #0577, name: Solosis
# index: 578, real national number: #0578, name: Duosion
# index: 579, real national number: #0579, name: Reuniclus
# index: 580, real national number: #0580, name: Ducklett
# index: 581, real national number: #0581, name: Swanna
# index: 582, real national number: #0582, name: Vanillite
# index: 583, real national number: #0583, name: Vanillish
# index: 584, real national number: #0584, name: Vanilluxe
# index: 585, real national number: #0585, name: DeerlingSpringForm
# index: 586, real national number: #0586, name: SawsbuckSpringForm
# index: 587, real national number: #0587, name: Emolga
# index: 588, real national number: #0588, name: Karrablast
# index: 589, real national number: #0589, name: Escavalier
# index: 590, real national number: #0590, name: Foongus
# index: 591, real national number: #0591, name: Amoonguss
# index: 592, real national number: #0592, name: Frillish
# index: 593, real national number: #0593, name: Jellicent
# index: 594, real national number: #0594, name: Alomomola
# index: 595, real national number: #0595, name: Joltik
# index: 596, real national number: #0596, name: Galvantula
# index: 597, real national number: #0597, name: Ferroseed
# index: 598, real national number: #0598, name: Ferrothorn
# index: 599, real national number: #0599, name: Klink
# index: 600, real national number: #0600, name: Klang
# index: 601, real national number: #0601, name: Klinklang
# index: 602, real national number: #0602, name: Tynamo
# index: 603, real national number: #0603, name: Eelektrik
# index: 604, real national number: #0604, name: Eelektross
# index: 605, real national number: #0605, name: Elgyem
# index: 606, real national number: #0606, name: Beheeyem
# index: 607, real national number: #0607, name: Litwick
# index: 608, real national number: #0608, name: Lampent
# index: 609, real national number: #0609, name: Chandelure
# index: 610, real national number: #0610, name: Axew
# index: 611, real national number: #0611, name: Fraxure
# index: 612, real national number: #0612, name: Haxorus
# index: 613, real national number: #0613, name: Cubchoo
# index: 614, real national number: #0614, name: Beartic
# index: 615, real national number: #0615, name: Cryogonal
# index: 616, real national number: #0616, name: Shelmet
# index: 617, real national number: #0617, name: Accelgor
# index: 618, real national number: #0618, name: Stunfisk
# index: 619, real national number: #0619, name: Mienfoo
# index: 620, real national number: #0620, name: Mienshao
# index: 621, real national number: #0621, name: Druddigon
# index: 622, real national number: #0622, name: Golett
# index: 623, real national number: #0623, name: Golurk
# index: 624, real national number: #0624, name: Pawniard
# index: 625, real national number: #0625, name: Bisharp
# index: 626, real national number: #0626, name: Bouffalant
# index: 627, real national number: #0627, name: Rufflet
# index: 628, real national number: #0628, name: Braviary
# index: 629, real national number: #0629, name: Vullaby
# index: 630, real national number: #0630, name: Mandibuzz
# index: 631, real national number: #0631, name: Heatmor
# index: 632, real national number: #0632, name: Durant
# index: 633, real national number: #0633, name: Deino
# index: 634, real national number: #0634, name: Zweilous
# index: 635, real national number: #0635, name: Hydreigon
# index: 636, real national number: #0636, name: Larvesta
# index: 637, real national number: #0637, name: Volcarona
# index: 638, real national number: #0638, name: Cobalion
# index: 639, real national number: #0639, name: Terrakion
# index: 640, real national number: #0640, name: Virizion
# index: 641, real national number: #0641, name: TornadusIncarnateForme
# index: 642, real national number: #0642, name: ThundurusIncarnateForme
# index: 643, real national number: #0643, name: Reshiram
# index: 644, real national number: #0644, name: Zekrom
# index: 645, real national number: #0645, name: LandorusIncarnateForme
# index: 646, real national number: #0646, name: KyuremKyurem
# index: 647, real national number: #0647, name: KeldeoOrdinaryForm
# index: 648, real national number: #0648, name: MeloettaAriaForme
# index: 649, real national number: #0649, name: GenesectGenesect(nodrive)
# index: 650, real national number: #0650, name: Chespin
# index: 651, real national number: #0651, name: Quilladin
# index: 652, real national number: #0652, name: Chesnaught
# index: 653, real national number: #0653, name: Fennekin
# index: 654, real national number: #0654, name: Braixen
# index: 655, real national number: #0655, name: Delphox
# index: 656, real national number: #0656, name: Froakie
# index: 657, real national number: #0657, name: Frogadier
# index: 658, real national number: #0658, name: Greninja
# index: 659, real national number: #0659, name: Bunnelby
# index: 660, real national number: #0660, name: Diggersby
# index: 661, real national number: #0661, name: Fletchling
# index: 662, real national number: #0662, name: Fletchinder
# index: 663, real national number: #0663, name: Talonflame
# index: 664, real national number: #0664, name: Scatterbug
# index: 665, real national number: #0665, name: Spewpa
# index: 666, real national number: #0666, name: VivillonMeadowPattern
# index: 667, real national number: #0667, name: Litleo
# index: 668, real national number: #0668, name: Pyroar
# index: 669, real national number: #0669, name: FlabébéRedFlower
# index: 670, real national number: #0670, name: FloetteRedFlower
# index: 671, real national number: #0671, name: FlorgesRedFlower
# index: 672, real national number: #0672, name: Skiddo
# index: 673, real national number: #0673, name: Gogoat
# index: 674, real national number: #0674, name: Pancham
# index: 675, real national number: #0675, name: Pangoro
# index: 676, real national number: #0676, name: FurfrouNaturalForm
# index: 677, real national number: #0677, name: Espurr
# index: 678, real national number: #0678, name: MeowsticMale
# index: 679, real national number: #0679, name: Honedge
# index: 680, real national number: #0680, name: Doublade
# index: 681, real national number: #0681, name: AegislashShieldForme
# index: 682, real national number: #0682, name: Spritzee
# index: 683, real national number: #0683, name: Aromatisse
# index: 684, real national number: #0684, name: Swirlix
# index: 685, real national number: #0685, name: Slurpuff
# index: 686, real national number: #0686, name: Inkay
# index: 687, real national number: #0687, name: Malamar
# index: 688, real national number: #0688, name: Binacle
# index: 689, real national number: #0689, name: Barbaracle
# index: 690, real national number: #0690, name: Skrelp
# index: 691, real national number: #0691, name: Dragalge
# index: 692, real national number: #0692, name: Clauncher
# index: 693, real national number: #0693, name: Clawitzer
# index: 694, real national number: #0694, name: Helioptile
# index: 695, real national number: #0695, name: Heliolisk
# index: 696, real national number: #0696, name: Tyrunt
# index: 697, real national number: #0697, name: Tyrantrum
# index: 698, real national number: #0698, name: Amaura
# index: 699, real national number: #0699, name: Aurorus
# index: 700, real national number: #0700, name: Sylveon
# index: 701, real national number: #0701, name: Hawlucha
# index: 702, real national number: #0702, name: Dedenne
# index: 703, real national number: #0703, name: Carbink
# index: 704, real national number: #0704, name: Goomy
# index: 705, real national number: #0705, name: Sliggoo
# index: 706, real national number: #0706, name: Goodra
# index: 707, real national number: #0707, name: Klefki
# index: 708, real national number: #0708, name: Phantump
# index: 709, real national number: #0709, name: Trevenant
# index: 710, real national number: #0710, name: Pumpkaboo
# index: 711, real national number: #0711, name: Gourgeist
# index: 712, real national number: #0712, name: Bergmite
# index: 713, real national number: #0713, name: Avalugg
# index: 714, real national number: #0714, name: Noibat
# index: 715, real national number: #0715, name: Noivern
# index: 716, real national number: #0716, name: XerneasNeutralMode
# index: 717, real national number: #0717, name: Yveltal
# index: 718, real national number: #0718, name: Zygarde50%Forme
# index: 719, real national number: #0719, name: Diancie
# index: 720, real national number: #0720, name: HoopaHoopaConfined
# index: 721, real national number: #0721, name: Volcanion
# index: 722, real national number: #0722, name: Rowlet
# index: 723, real national number: #0723, name: Dartrix
# index: 724, real national number: #0724, name: Decidueye
# index: 725, real national number: #0725, name: Litten
# index: 726, real national number: #0726, name: Torracat
# index: 727, real national number: #0727, name: Incineroar
# index: 728, real national number: #0728, name: Popplio
# index: 729, real national number: #0729, name: Brionne
# index: 730, real national number: #0730, name: Primarina
# index: 731, real national number: #0731, name: Pikipek
# index: 732, real national number: #0732, name: Trumbeak
# index: 733, real national number: #0733, name: Toucannon
# index: 734, real national number: #0734, name: Yungoos
# index: 735, real national number: #0735, name: Gumshoos
# index: 736, real national number: #0736, name: Grubbin
# index: 737, real national number: #0737, name: Charjabug
# index: 738, real national number: #0738, name: Vikavolt
# index: 739, real national number: #0739, name: Crabrawler
# index: 740, real national number: #0740, name: Crabominable
# index: 741, real national number: #0741, name: OricorioBaileStyle
# index: 742, real national number: #0742, name: Cutiefly
# index: 743, real national number: #0743, name: Ribombee
# index: 744, real national number: #0744, name: Rockruff
# index: 745, real national number: #0745, name: LycanrocMiddayForm
# index: 746, real national number: #0746, name: WishiwashiSoloForm
# index: 747, real national number: #0747, name: Mareanie
# index: 748, real national number: #0748, name: Toxapex
# index: 749, real national number: #0749, name: Mudbray
# index: 750, real national number: #0750, name: Mudsdale
# index: 751, real national number: #0751, name: Dewpider
# index: 752, real national number: #0752, name: Araquanid
# index: 753, real national number: #0753, name: Fomantis
# index: 754, real national number: #0754, name: Lurantis
# index: 755, real national number: #0755, name: Morelull
# index: 756, real national number: #0756, name: Shiinotic
# index: 757, real national number: #0757, name: Salandit
# index: 758, real national number: #0758, name: Salazzle
# index: 759, real national number: #0759, name: Stufful
# index: 760, real national number: #0760, name: Bewear
# index: 761, real national number: #0761, name: Bounsweet
# index: 762, real national number: #0762, name: Steenee
# index: 763, real national number: #0763, name: Tsareena
# index: 764, real national number: #0764, name: Comfey
# index: 765, real national number: #0765, name: Oranguru
# index: 766, real national number: #0766, name: Passimian
# index: 767, real national number: #0767, name: Wimpod
# index: 768, real national number: #0768, name: Golisopod
# index: 769, real national number: #0769, name: Sandygast
# index: 770, real national number: #0770, name: Palossand
# index: 771, real national number: #0771, name: Pyukumuku
# index: 772, real national number: #0772, name: Type:Null
# index: 773, real national number: #0773, name: SilvallyType:Normal
# index: 774, real national number: #0774, name: MiniorMeteorForm
# index: 775, real national number: #0775, name: Komala
# index: 776, real national number: #0776, name: Turtonator
# index: 777, real national number: #0777, name: Togedemaru
# index: 778, real national number: #0778, name: MimikyuDisguisedForm
# index: 779, real national number: #0779, name: Bruxish
# index: 780, real national number: #0780, name: Drampa
# index: 781, real national number: #0781, name: Dhelmise
# index: 782, real national number: #0782, name: Jangmo-o
# index: 783, real national number: #0783, name: Hakamo-o
# index: 784, real national number: #0784, name: Kommo-o
# index: 785, real national number: #0785, name: TapuKoko
# index: 786, real national number: #0786, name: TapuLele
# index: 787, real national number: #0787, name: TapuBulu
# index: 788, real national number: #0788, name: TapuFini
# index: 789, real national number: #0789, name: Cosmog
# index: 790, real national number: #0790, name: Cosmoem
# index: 791, real national number: #0791, name: Solgaleo
# index: 792, real national number: #0792, name: Lunala
# index: 793, real national number: #0793, name: Nihilego
# index: 794, real national number: #0794, name: Buzzwole
# index: 795, real national number: #0795, name: Pheromosa
# index: 796, real national number: #0796, name: Xurkitree
# index: 797, real national number: #0797, name: Celesteela
# index: 798, real national number: #0798, name: Kartana
# index: 799, real national number: #0799, name: Guzzlord
# index: 800, real national number: #0800, name: Necrozma
# index: 801, real national number: #0801, name: Magearna
# index: 802, real national number: #0802, name: Marshadow
# index: 803, real national number: #0803, name: Poipole
# index: 804, real national number: #0804, name: Naganadel
# index: 805, real national number: #0805, name: Stakataka
# index: 806, real national number: #0806, name: Blacephalon
# index: 807, real national number: #0807, name: Zeraora
# index: 808, real national number: #0808, name: Meltan
# index: 809, real national number: #0809, name: Melmetal
# index: 810, real national number: #0810, name: Grookey
# index: 811, real national number: #0811, name: Thwackey
# index: 812, real national number: #0812, name: Rillaboom
# index: 813, real national number: #0813, name: Scorbunny
# index: 814, real national number: #0814, name: Raboot
# index: 815, real national number: #0815, name: Cinderace
# index: 816, real national number: #0816, name: Sobble
# index: 817, real national number: #0817, name: Drizzile
# index: 818, real national number: #0818, name: Inteleon
# index: 819, real national number: #0819, name: Skwovet
# index: 820, real national number: #0820, name: Greedent
# index: 821, real national number: #0821, name: Rookidee
# index: 822, real national number: #0822, name: Corvisquire
# index: 823, real national number: #0823, name: Corviknight
# index: 824, real national number: #0824, name: Blipbug
# index: 825, real national number: #0825, name: Dottler
# index: 826, real national number: #0826, name: Orbeetle
# index: 827, real national number: #0827, name: Nickit
# index: 828, real national number: #0828, name: Thievul
# index: 829, real national number: #0829, name: Gossifleur
# index: 830, real national number: #0830, name: Eldegoss
# index: 831, real national number: #0831, name: Wooloo
# index: 832, real national number: #0832, name: Dubwool
# index: 833, real national number: #0833, name: Chewtle
# index: 834, real national number: #0834, name: Drednaw
# index: 835, real national number: #0835, name: Yamper
# index: 836, real national number: #0836, name: Boltund
# index: 837, real national number: #0837, name: Rolycoly
# index: 838, real national number: #0838, name: Carkol
# index: 839, real national number: #0839, name: Coalossal
# index: 840, real national number: #0840, name: Applin
# index: 841, real national number: #0841, name: Flapple
# index: 842, real national number: #0842, name: Appletun
# index: 843, real national number: #0843, name: Silicobra
# index: 844, real national number: #0844, name: Sandaconda
# index: 845, real national number: #0845, name: Cramorant
# index: 846, real national number: #0846, name: Arrokuda
# index: 847, real national number: #0847, name: Barraskewda
# index: 848, real national number: #0848, name: Toxel
# index: 849, real national number: #0849, name: ToxtricityAmpedForm
# index: 850, real national number: #0850, name: Sizzlipede
# index: 851, real national number: #0851, name: Centiskorch
# index: 852, real national number: #0852, name: Clobbopus
# index: 853, real national number: #0853, name: Grapploct
# index: 854, real national number: #0854, name: Sinistea
# index: 855, real national number: #0855, name: Polteageist
# index: 856, real national number: #0856, name: Hatenna
# index: 857, real national number: #0857, name: Hattrem
# index: 858, real national number: #0858, name: Hatterene
# index: 859, real national number: #0859, name: Impidimp
# index: 860, real national number: #0860, name: Morgrem
# index: 861, real national number: #0861, name: Grimmsnarl
# index: 862, real national number: #0862, name: Obstagoon
# index: 863, real national number: #0863, name: Perrserker
# index: 864, real national number: #0864, name: Cursola
# index: 865, real national number: #0865, name: Sirfetch'd
# index: 866, real national number: #0866, name: Mr.Rime
# index: 867, real national number: #0867, name: Runerigus
# index: 868, real national number: #0868, name: Milcery
# index: 869, real national number: #0869, name: AlcremieVanillaCream
# index: 870, real national number: #0870, name: Falinks
# index: 871, real national number: #0871, name: Pincurchin
# index: 872, real national number: #0872, name: Snom
# index: 873, real national number: #0873, name: Frosmoth
# index: 874, real national number: #0874, name: Stonjourner
# index: 875, real national number: #0875, name: EiscueIceFace
# index: 876, real national number: #0876, name: IndeedeeMale
# index: 877, real national number: #0877, name: MorpekoFullBellyMode
# index: 878, real national number: #0878, name: Cufant
# index: 879, real national number: #0879, name: Copperajah
# index: 880, real national number: #0880, name: Dracozolt
# index: 881, real national number: #0881, name: Arctozolt
# index: 882, real national number: #0882, name: Dracovish
# index: 883, real national number: #0883, name: Arctovish
# index: 884, real national number: #0884, name: Duraludon
# index: 885, real national number: #0885, name: Dreepy
# index: 886, real national number: #0886, name: Drakloak
# index: 887, real national number: #0887, name: Dragapult
# index: 888, real national number: #0888, name: ZacianHeroofManyBattles
# index: 889, real national number: #0889, name: ZamazentaHeroofManyBattles
# index: 890, real national number: #0890, name: Eternatus
# index: 891, real national number: #0891, name: Kubfu
# index: 892, real national number: #0892, name: UrshifuSingleStrikeStyle
# index: 893, real national number: #0893, name: Zarude
# index: 894, real national number: #0894, name: Regieleki
# index: 895, real national number: #0895, name: Regidrago
# index: 896, real national number: #0896, name: Glastrier
# index: 897, real national number: #0897, name: Spectrier
# index: 898, real national number: #0898, name: Calyrex
# index: 899, real national number: #0899, name: Wyrdeer
# index: 900, real national number: #0900, name: Kleavor
# index: 901, real national number: #0901, name: Ursaluna
# index: 902, real national number: #0902, name: BasculegionMale
# index: 903, real national number: #0903, name: Sneasler
# index: 904, real national number: #0904, name: Overqwil
# index: 905, real national number: #0905, name: EnamorusIncarnateForme
# index: 906, real national number: #0906, name: Sprigatito
# index: 907, real national number: #0907, name: Floragato
# index: 908, real national number: #0908, name: Meowscarada
# index: 909, real national number: #0909, name: Fuecoco
# index: 910, real national number: #0910, name: Crocalor
# index: 911, real national number: #0911, name: Skeledirge
# index: 912, real national number: #0912, name: Quaxly
# index: 913, real national number: #0913, name: Quaxwell
# index: 914, real national number: #0914, name: Quaquaval
# index: 915, real national number: #0915, name: Lechonk
# index: 916, real national number: #0916, name: OinkologneMale
# index: 917, real national number: #0917, name: Tarountula
# index: 918, real national number: #0918, name: Spidops
# index: 919, real national number: #0919, name: Nymble
# index: 920, real national number: #0920, name: Lokix
# index: 921, real national number: #0921, name: Pawmi
# index: 922, real national number: #0922, name: Pawmo
# index: 923, real national number: #0923, name: Pawmot
# index: 924, real national number: #0924, name: Tandemaus
# index: 925, real national number: #0925, name: MausholdFamilyofThree
# index: 926, real national number: #0926, name: Fidough
# index: 927, real national number: #0927, name: Dachsbun
# index: 928, real national number: #0928, name: Smoliv
# index: 929, real national number: #0929, name: Dolliv
# index: 930, real national number: #0930, name: Arboliva
# index: 931, real national number: #0931, name: SquawkabillyGreenPlumage
# index: 932, real national number: #0932, name: Nacli
# index: 933, real national number: #0933, name: Naclstack
# index: 934, real national number: #0934, name: Garganacl
# index: 935, real national number: #0935, name: Charcadet
# index: 936, real national number: #0936, name: Armarouge
# index: 937, real national number: #0937, name: Ceruledge
# index: 938, real national number: #0938, name: Tadbulb
# index: 939, real national number: #0939, name: Bellibolt
# index: 940, real national number: #0940, name: Wattrel
# index: 941, real national number: #0941, name: Kilowattrel
# index: 942, real national number: #0942, name: Maschiff
# index: 943, real national number: #0943, name: Mabosstiff
# index: 944, real national number: #0944, name: Shroodle
# index: 945, real national number: #0945, name: Grafaiai
# index: 946, real national number: #0946, name: Bramblin
# index: 947, real national number: #0947, name: Brambleghast
# index: 948, real national number: #0948, name: Toedscool
# index: 949, real national number: #0949, name: Toedscruel
# index: 950, real national number: #0950, name: Klawf
# index: 951, real national number: #0951, name: Capsakid
# index: 952, real national number: #0952, name: Scovillain
# index: 953, real national number: #0953, name: Rellor
# index: 954, real national number: #0954, name: Rabsca
# index: 955, real national number: #0955, name: Flittle
# index: 956, real national number: #0956, name: Espathra
# index: 957, real national number: #0957, name: Tinkatink
# index: 958, real national number: #0958, name: Tinkatuff
# index: 959, real national number: #0959, name: Tinkaton
# index: 960, real national number: #0960, name: Wiglett
# index: 961, real national number: #0961, name: Wugtrio
# index: 962, real national number: #0962, name: Bombirdier
# index: 963, real national number: #0963, name: Finizen
# index: 964, real national number: #0964, name: PalafinZeroForm
# index: 965, real national number: #0965, name: Varoom
# index: 966, real national number: #0966, name: Revavroom
# index: 967, real national number: #0967, name: Cyclizar
# index: 968, real national number: #0968, name: Orthworm
# index: 969, real national number: #0969, name: Glimmet
# index: 970, real national number: #0970, name: Glimmora
# index: 971, real national number: #0971, name: Greavard
# index: 972, real national number: #0972, name: Houndstone
# index: 973, real national number: #0973, name: Flamigo
# index: 974, real national number: #0974, name: Cetoddle
# index: 975, real national number: #0975, name: Cetitan
# index: 976, real national number: #0976, name: Veluza
# index: 977, real national number: #0977, name: Dondozo
# index: 978, real national number: #0978, name: TatsugiriCurlyForm
# index: 979, real national number: #0979, name: Annihilape
# index: 980, real national number: #0980, name: Clodsire
# index: 981, real national number: #0981, name: Farigiraf
# index: 982, real national number: #0982, name: DudunsparceTwo-SegmentForm
# index: 983, real national number: #0983, name: Kingambit
# index: 984, real national number: #0984, name: GreatTusk
# index: 985, real national number: #0985, name: ScreamTail
# index: 986, real national number: #0986, name: BruteBonnet
# index: 987, real national number: #0987, name: FlutterMane
# index: 988, real national number: #0988, name: SlitherWing
# index: 989, real national number: #0989, name: SandyShocks
# index: 990, real national number: #0990, name: IronTreads
# index: 991, real national number: #0991, name: IronBundle
# index: 992, real national number: #0992, name: IronHands
# index: 993, real national number: #0993, name: IronJugulis
# index: 994, real national number: #0994, name: IronMoth
# index: 995, real national number: #0995, name: IronThorns
# index: 996, real national number: #0996, name: Frigibax
# index: 997, real national number: #0997, name: Arctibax
# index: 998, real national number: #0998, name: Baxcalibur
# index: 999, real national number: #0999, name: GimmighoulChestForm
# index: 1000, real national number: #1000, name: Gholdengo
# index: 1001, real national number: #1001, name: Wo-Chien
# index: 1002, real national number: #1002, name: Chien-Pao
# index: 1003, real national number: #1003, name: Ting-Lu
# index: 1004, real national number: #1004, name: Chi-Yu
# index: 1005, real national number: #1005, name: RoaringMoon
# index: 1006, real national number: #1006, name: IronValiant
# index: 1007, real national number: #1007, name: KoraidonApexBuild
# index: 1008, real national number: #1008, name: MiraidonUltimateMode
# index: 1009, real national number: #1009, name: WalkingWake
# index: 1010, real national number: #1010, name: IronLeaves
# index: 1011, real national number: #1011, name: Dipplin
# index: 1012, real national number: #1012, name: Poltchageist
# index: 1013, real national number: #1013, name: Sinistcha
# index: 1014, real national number: #1014, name: Okidogi
# index: 1015, real national number: #1015, name: Munkidori
# index: 1016, real national number: #1016, name: Fezandipiti
# index: 1017, real national number: #1017, name: OgerponTealMask
# index: 1018, real national number: #1018, name: Archaludon
# index: 1019, real national number: #1019, name: Hydrapple
# index: 1020, real national number: #1020, name: GougingFire
# index: 1021, real national number: #1021, name: RagingBolt
# index: 1022, real national number: #1022, name: IronBoulder
# index: 1023, real national number: #1023, name: IronCrown
# index: 1024, real national number: #1024, name: TerapagosNormalForm
# index: 1025, real national number: #1025, name: Pecharunt

# %%
pokemon_names = df['Pokémon'].to_list()

# %%
pokemon_names = [item.lower() for item in pokemon_names]

# %%
print(pokemon_names[0:5])
# Out:
# ['bulbasaur', 'ivysaur', 'venusaur', 'charmander', 'charmeleon']

# %%
form_name_mapping = {
    'unownoneform': "unown",
    'castformnormal': "castform",
    'deoxysnormalforme': "deoxys",
    'cherrimovercastform': "cherrim",
    'giratinaalteredforme': "giratina",
    'shayminlandforme': "shaymin",
    'basculinred-stripedform': "basculin",
    'deerlingspringform': "deerling",
    'sawsbuckspringform': "sawsbuck",
    'tornadusincarnateforme': "tornadus",
    'thundurusincarnateforme': "thundurus",
    'landorusincarnateforme': "landorus",
    'keldeoordinaryform': "keldeo",
    'meloettaariaforme': "meloetta",
    'furfrounaturalform': "furfrou",
    'aegislashshieldforme': "aegislash",
    'zygarde50%forme': "zygarde",
    'lycanrocmiddayform': "lycanroc",
    'wishiwashisoloform': "wishiwashi",
    'miniormeteorform': "minior",
    'mimikyudisguisedform': "mimikyu",
    'toxtricityampedform': "toxtricity",
    'enamorusincarnateforme': "enamorus",
    'palafinzeroform': "palafin",
    'tatsugiricurlyform': "tatsugiri",
    'dudunsparcetwo-segmentform': "dudunsparce",
    'gimmighoulchestform': "gimmighoul",
    'terapagosnormalform': "terapagos"
}
pokemon_names = [form_name_mapping.get(name, name) for name in pokemon_names]
form_names = [name for name in pokemon_names if "form" in name]
print(form_names)
# Out:
# ['castform']

# %%
# there are some keywords, which now appear in the table with pokemon names. 
# These pokemon have specifier like "fire type" or "red flower" in the name from the table. 
# we need to see this, so we can remove it in the next cell
keywords = [
    "Kyurem", "mode", "rotom", "sea", "cloak", "bre", "flower", "Genesect", "Male", "hoopa",
    "style", "core", "type", "Mane", "wings", "face", "hero", "crown", "rider", "moon",
    "plumage", "mask"
]
keywords = [k.lower() for k in keywords]

matches = {}
for keyword in keywords:
    matches[keyword] = [name for name in pokemon_names if keyword in name]

for keyword, names in matches.items():
    print(f"{keyword}: {names}")
# Out:
# kyurem: ['kyuremkyurem']
# mode: ['darmanitanstandardmode', 'xerneasneutralmode', 'morpekofullbellymode', 'miraidonultimatemode']
# rotom: ['rotomrotom']
# sea: ['horsea', 'seadra', 'seaking', 'sealeo', 'shelloswestsea', 'gastrodonwestsea', 'pansear', 'simisear']
# cloak: ['burmyplantcloak', 'wormadamplantcloak']
# bre: ['umbreon', 'lombre', 'breloom']
# flower: ['flabébéredflower', 'floetteredflower', 'florgesredflower']
# genesect: ['genesectgenesect(nodrive)']
# male: ['meowsticmale', 'indeedeemale', 'basculegionmale', 'oinkolognemale']
# hoopa: ['hoopahoopaconfined']
# style: ['oricoriobailestyle', 'urshifusinglestrikestyle']
# core: []
# type: ['type:null', 'silvallytype:normal']
# mane: ['manectric', 'fluttermane']
# wings: []
# face: ['eiscueiceface']
# hero: ['pheromosa', 'zacianheroofmanybattles', 'zamazentaheroofmanybattles']
# crown: ['ironcrown']
# rider: []
# moon: ['amoonguss', 'roaringmoon']
# plumage: ['squawkabillygreenplumage']
# mask: ['yamask', 'ogerpontealmask']

# %%
category_name_mapping = {
    'kyuremkyurem': 'kyurem',
    'darmanitanstandardmode': 'darmanitan',
    'xerneasneutralmode': 'xerneas',
    'morpekofullbellymode': 'morpeko',
    'miraidonultimatemode': 'miraidon',
    'rotomrotom': 'rotom',
    'shelloswestsea': 'shellos',
    'gastrodonwestsea': 'gastrodon',
    'burmyplantcloak': 'burmy',
    'wormadamplantcloak': 'wormadam',
    'flabébéredflower': 'flabébé',
    'floetteredflower': 'floette',
    'florgesredflower': 'florges',
    'genesectgenesect(nodrive)': 'genesect',
    'meowsticmale': 'meowstic',
    'indeedeemale': 'indeedee',
    'basculegionmale': 'basculegion',
    'oinkolognemale': 'oinkologne',
    'hoopahoopaconfined': 'hoopa',
    'mausholdfamilyofthree': 'maushold',
    'koraidonapexbuild': 'koraidon',
    'oricoriobailestyle': 'oricorio',
    'urshifusinglestrikestyle': 'urshifu',
    'type:null': 'type:null',
    'silvallytype:normal': 'silvally',
    'fluttermane': 'flutter mane',
    'eiscueiceface': 'eiscue',
    'zacianheroofmanybattles': 'zacian',
    'zamazentaheroofmanybattles': 'zamazenta',
    'ironcrown': 'iron crown',
    'roaringmoon': 'roaring moon',
    'squawkabillygreenplumage': 'squawkabilly',
    'ogerpontealmask': 'ogerpon',
    'kyogrekyogre': 'kyogre',
    'groudongroudon': 'groudon',
    'alcremievanillacream': 'alcremie',
}

pokemon_names = [category_name_mapping.get(name, name) for name in pokemon_names]

# %% [markdown]
# Now we will use the primary data source of Serebii.net using their Gen IX pokedex

# %%
url = "https://www.serebii.net/pokedex-sv/{}/#stats"

# %%
def get_number(soup):
    tables = soup.find_all("table", class_="dextable")
    if len(tables) < 2:
        return None
    table = tables[1]
    try:
        num = table.find_all("tr")[1].find_all("td", class_="fooinfo")[2].text.strip().split('\n')[0].split("#")[-1]
        return num
    except Exception:
        return None

# %%
def get_name(soup):
    table = soup.find_all("table", class_="dextable")[1]
    name = table.find_all("tr")[1].find_all("td")[0].text
    
    return name

# %%
def get_altnames(soup):
    altnames = {}
    table = soup.find_all("table", class_="dextable")[1]
    rows = table.find_all("tr")[1].find_all("td")[1].find_all("tr")
    for row in rows:
        key = row.find_all("td")[0].text.strip().replace(":","")
        contents = row.find_all("td")[1].contents
        value = [x for x in contents if isinstance(x, type(contents[0]))]
        altnames[key] = value
    
    return altnames

# %%
def get_type(soup):
    types = []
    table = soup.find_all("table", class_="dextable")[1]
    imgs = table.find_all("img")
    for img in imgs:
        types.append(img["src"].split("/")[-1].split(".")[0])
    
    return types

# %%
def get_gender(soup):
    gender_ratios = {}
    table = soup.find_all("table", class_="dextable")[1]
    try:  #genderless pokemon will cause exception
        rows = table.find_all("tr")[1].find_all("td", class_="fooinfo")[3].contents[0].find_all("tr")
        for row in rows:
            key = row.find_all("td")[0].text.split(" ")[0]
            value = row.find_all("td")[1].text
            gender_ratios[key] = value
    except:
        gender_ratios['Male'] = '0'
        gender_ratios['Female'] = '0'

    return gender_ratios

# %%
def get_classification(soup):
    table = soup.find_all("table", class_="dextable")[1]
    classification = table.find_all("td", class_="fooinfo")[4].text
    
    return classification

# %%
def get_height(soup):
    table = soup.find_all("table", class_="dextable")[1]
    height = table.find_all("td", class_="fooinfo")[5].text.split("\t")[-1]
    
    return height

# %%
def get_weight(soup):
    table = soup.find_all("table", class_="dextable")[1]
    weight = table.find_all("td", class_="fooinfo")[6].text.split("\t")[-1]
    
    return weight

# %%
def get_capture_rate(soup):
    table = soup.find_all("table", class_="dextable")[1]
    rate = table.find_all("td", class_="fooinfo")[7].text.split("\t")[-1]
    
    return rate

# %%
def get_base_egg_steps(soup):
    table = soup.find_all("table", class_="dextable")[1]
    steps = table.find_all("td", class_="fooinfo")[8].text.split("\t")[-1].replace(",","")
    
    steps = steps.split()[0]
    return steps

# %%
def get_base_stats(soup):
    base_stats = {}
    stat_names = ["HP","Attack","Defense","Sp. Attack","Sp. Defense","Speed"]

    stats_indices = []
    for row in soup.find_all("tr"):
        if 'Stats' == row.text.replace('\n',''):
            stats_indices.append(soup.find_all("tr").index(row))

    try:
        columns = soup.find_all("tr")[stats_indices[0]+2].find_all("td")

    except:
        columns = soup.find_all("tr")[stats_indices[1]+2].find_all("td")

    for i in range(len(stat_names)):
        base_stats[stat_names[i]] = columns[i+1].text

    return base_stats

# %%
def get_legendary_status(name):
                
    legendary_status = {"sublegendary": 0, "legendary": 0, "mythical": 0}
    if name in status_dict["sublegendary"]:
        legendary_status["sublegendary"] = 1
    elif name in status_dict["legendary"]:
        legendary_status["legendary"] = 1
    elif name in status_dict["mythical"]:
        legendary_status["mythical"] = 1
    
    return legendary_status

# %%
def get_experience_growth(soup):
    table = soup.find_all("table", class_="dextable")[2].find_all("tr", recursive=False)[3]
    exp = table.find_all("tr", recursive=False)[3].td.contents[0].split(" ")[0].replace(",","")
    
    return exp

# %%
def get_base_happiness(soup):
    table = soup.find_all("table", class_="dextable")[2].find_all("tr", recursive=False)[3]
    happiness = table.find_all("tr", recursive=False)[3].find_all("td",recursive=False)[1].text
    
    return happiness

# %%
def get_against(soup):
    headers = []
    against_dict = {}
    links = soup.find_all("table", class_="dextable")[3].find_all("tr",recursive=False)[1].find_all("a")
    for link in links:
        header = link['href'].split("/")[-1].split(".")[0]
        headers.append(header)
    
    columns = soup.find_all("table", class_="dextable")[3].find_all("tr",recursive=False)[2].find_all('td')
    for i in range(len(headers)):
        against_dict[headers[i]] = columns[i].text.split('*')[-1]
    
    return against_dict

# %%
def get_abilities(soup):
    table = soup.find_all("table", class_="dextable")[2]
    abilities = table.find_all('tr')[0].text.split(": ")[1].strip().split(" - ")
    
    return abilities

# %%
def get_gen(number):
    if int(number) <= 151:
        gen = 'I'
    elif int(number) <= 251:
        gen = 'II'
    elif int(number) <= 386:
        gen = 'III'
    elif int(number) <= 493:
        gen = 'IV'
    elif int(number) <= 649:
        gen = 'V'
    elif int(number) <= 721:
        gen = 'VI'
    elif int(number) <= 809:
        gen = 'VII'
    elif int(number) <= 905:
        gen = 'VIII'
    elif int(number) <= 1025:
        gen = 'IX'
    else:
        gen = 'X'
    
    return gen

# %%
def get_description(name):
    name = name.replace("'",'').replace(' ','-').replace('.',' ').strip().replace(' ','-').replace(':','-')
    if name == 'nidoran♀':
        name = 'nidoran-female'
    elif name == 'nidoran♂':
        name = 'nidoran-male'
    elif name == 'mimejr':
        name = 'mime-jr'
    elif name[:4] == 'tapu':
        name = name[:4] + '-' + name[4:]
    elif name == 'type:null':
        name = 'type-null'
    elif name == 'flutter mane':
        name = 'flutter-mane'
    elif name == 'iron crown':
        name = 'iron-crown'
    elif name =="roaring moon":
        name = "roaring-moon"
    try:
        url = 'https://www.pokemon.com/us/pokedex/{}'
        r = requests.get(url.format(name))
        soup = BeautifulSoup(r.text, "html.parser")
        desc = soup.find('div', class_='version-descriptions active').find('p', class_='active').contents[0].strip()
    except:
        desc = ''

    return desc

# %%
def get_evochain(soup):
    table = soup.find_all("table", class_="evochain")[0]
    chain = []
    if len(table.find_all('tr')) == 1:
        for img in table.find_all('img'):
            try:
                a = img['title']
                chain.append(a)   
            except:
                try:
                    a = img['alt']
                    chain.append(a) 
                except:
                    pass
    
    elif table.find('a')['href'].split('/')[1] == 'pokedex-sv':
        row = table.find('tr')
        for col in row.find_all('td')[:7]:
            try:
                a = col.find('img')['title'].strip()
            except:
                try:
                    a = col.find('img')['alt'].strip()
                except:
                    number = col.find('a')['href'].split('/')[-1].split('.')[0]
                    a = pokemon_names[int(number)-1].capitalize()
            chain.append(a)
    
    else:
        for col in table.find_all('td')[:7]:
            try:
                a = col.find('img')['title'].strip()
            except:
                try:
                    a = col.find('img')['alt'].strip()
                except:
                    try:
                        number = col.find('img')['src'].split('/')[-1].split('.')[0]
                        a = pokemon_names[int(number)-1].capitalize()
                    except:
                        pass
                    #a = col.find('a')['href'].split('/')[-1].capitalize()
            chain.append(a)
    
    if len(chain)>1:
        if chain[0] == chain[1]:
            chain.pop(0)
    
        if len(chain)>3 and chain[2] == chain[3]:
            try:
                chain.pop(5)
            except:
                pass
            chain.pop(4)
            chain.pop(3)

        try:
            if chain[4] == chain[5]:
                chain.pop(6)
                chain.pop(5)
        except:
            pass 
    
    return chain

# %%
pokedex = pd.DataFrame()
url = "https://www.serebii.net/pokemon/legendary.shtml"
r = requests.get(url)
soup = BeautifulSoup(r.text, "html.parser")
tables = soup.find_all("table", class_="trainer")
status_list = ["sublegendary","legendary","mythical"]
status_dict = {}
for i in range(len(tables)):
    status_dict[status_list[i]] = []
    for row in tables[i].find_all("tr", recursive=False)[1:-1]:
        for column in row.find_all("td", recursive=False):
            item = column.find_all('td')[1].text
            status_dict[status_list[i]].append(item)
            
for index, pokemon in enumerate(pokemon_names):
    if index <= 898: #skip almost to gen IX
        continue
    print("Processing {} index: {}".format(pokemon,index)   )
    stats = {}


    pokemon_search = pokemon.replace(" ", "")
    
    try:
        url = "https://www.serebii.net/pokedex-sv/{}/#stats"
        r = requests.get(url.format(pokemon_search))
        soup = BeautifulSoup(r.text, "html.parser")
        check = soup.find_all("table", class_="dextable")[1]
    except:
        url = "https://www.serebii.net/pokedex-swsh/{}.shtml"
        number = "{0:0=3d}".format(pokemon_names.index(pokemon_search)+1)
        r = requests.get(url.format(number))
        soup = BeautifulSoup(r.text, "html.parser")
    
    stats['national_number'] = get_number(soup)
    if stats['national_number'] is None:
        print("Skipping {}, no national number found.".format(pokemon))
        continue
    
    stats['gen'] = get_gen(stats['national_number'])
    stats['english_name'] = get_name(soup)
    stats['japanese_name'] = get_altnames(soup)['Japan'][0]
    stats['primary_type'] = get_type(soup)[0]
    stats['secondary_type'] = get_type(soup)[1] if len(get_type(soup))>1 else None 
    stats['percent_male'] = get_gender(soup)['Male'].replace('%','') if len(get_gender(soup))>1 else None
    stats['percent_female'] = get_gender(soup)['Female'].replace('%','') if len(get_gender(soup))>1 else None
    stats['classification'] = get_classification(soup)
    stats['height_m'] = get_height(soup).split('m')[0]
    stats['weight_kg'] = get_weight(soup).split('kg')[0]
    stats['capture_rate'] = get_capture_rate(soup)
    stats['base_egg_steps'] = get_base_egg_steps(soup)
    stats['hp'] = get_base_stats(soup)["HP"]
    stats['attack'] = get_base_stats(soup)["Attack"]
    stats['defense'] = get_base_stats(soup)["Defense"]
    stats['sp_attack'] = get_base_stats(soup)["Sp. Attack"]
    stats['sp_defense'] = get_base_stats(soup)["Sp. Defense"]
    stats['speed'] = get_base_stats(soup)["Speed"]
    stats['description'] = get_description(pokemon)
    
    abilities = get_abilities(soup)
    for i in range(3):
        try:
            if 'Hidden' not in abilities[i]:
                stats['abilities_{}'.format(i)] = abilities[i]
            elif 'Hidden' in abilities[i]:
                stats['abilities_hidden'] = abilities[i].split('(')[0].strip()
        except:
             stats['abilities_{}'.format(i)] = None
                
    for i in range(7):
        try:
            stats['evochain_{}'.format(i)] = get_evochain(soup)[i]
        except:
            stats['evochain_{}'.format(i)] = None
    
    legend = get_legendary_status(stats['english_name'])
    for i in legend.keys():
        stats['is_{}'.format(i)] = legend[i]
    
    against = get_against(soup)
    for i in against.keys():
        stats['against_{}'.format(i)] = against[i]
    pokedex = pd.concat([pokedex, pd.DataFrame([stats])], ignore_index=True)
# Out:
# Processing kleavor index: 899
# Processing ursaluna index: 900
# Processing basculegion index: 901
# Processing sneasler index: 902
# Processing overqwil index: 903
# Processing enamorus index: 904
# Processing sprigatito index: 905
# Processing floragato index: 906
# Processing meowscarada index: 907
# Processing fuecoco index: 908
# Processing crocalor index: 909
# Processing skeledirge index: 910
# Processing quaxly index: 911
# Processing quaxwell index: 912
# Processing quaquaval index: 913
# Processing lechonk index: 914
# Processing oinkologne index: 915
# Processing tarountula index: 916
# Processing spidops index: 917
# Processing nymble index: 918
# Processing lokix index: 919
# Processing pawmi index: 920
# Processing pawmo index: 921
# Processing pawmot index: 922
# Processing tandemaus index: 923
# Processing maushold index: 924
# Processing fidough index: 925
# Processing dachsbun index: 926
# Processing smoliv index: 927
# Processing dolliv index: 928
# Processing arboliva index: 929
# Processing squawkabilly index: 930
# Processing nacli index: 931
# Processing naclstack index: 932
# Processing garganacl index: 933
# Processing charcadet index: 934
# Processing armarouge index: 935
# Processing ceruledge index: 936
# Processing tadbulb index: 937
# Processing bellibolt index: 938
# Processing wattrel index: 939
# Processing kilowattrel index: 940
# Processing maschiff index: 941
# Processing mabosstiff index: 942
# Processing shroodle index: 943
# Processing grafaiai index: 944
# Processing bramblin index: 945
# Processing brambleghast index: 946
# Processing toedscool index: 947
# Processing toedscruel index: 948
# Processing klawf index: 949
# Processing capsakid index: 950
# Processing scovillain index: 951
# Processing rellor index: 952
# Processing rabsca index: 953
# Processing flittle index: 954
# Processing espathra index: 955
# Processing tinkatink index: 956
# Processing tinkatuff index: 957
# Processing tinkaton index: 958
# Processing wiglett index: 959
# Processing wugtrio index: 960
# Processing bombirdier index: 961
# Processing finizen index: 962
# Processing palafin index: 963
# Processing varoom index: 964
# Processing revavroom index: 965
# Processing cyclizar index: 966
# Processing orthworm index: 967
# Processing glimmet index: 968
# Processing glimmora index: 969
# Processing greavard index: 970
# Processing houndstone index: 971
# Processing flamigo index: 972
# Processing cetoddle index: 973
# Processing cetitan index: 974
# Processing veluza index: 975
# Processing dondozo index: 976
# Processing tatsugiri index: 977
# Processing annihilape index: 978
# Processing clodsire index: 979
# Processing farigiraf index: 980
# Processing dudunsparce index: 981
# Processing kingambit index: 982
# Processing greattusk index: 983
# Processing screamtail index: 984
# Processing brutebonnet index: 985
# Processing flutter mane index: 986
# Processing slitherwing index: 987
# Processing sandyshocks index: 988
# Processing irontreads index: 989
# Processing ironbundle index: 990
# Processing ironhands index: 991
# Processing ironjugulis index: 992
# Processing ironmoth index: 993
# Processing ironthorns index: 994
# Processing frigibax index: 995
# Processing arctibax index: 996
# Processing baxcalibur index: 997
# Processing gimmighoul index: 998
# Processing gholdengo index: 999
# Processing wo-chien index: 1000
# Processing chien-pao index: 1001
# Processing ting-lu index: 1002
# Processing chi-yu index: 1003
# Processing roaring moon index: 1004
# Processing ironvaliant index: 1005
# Processing koraidon index: 1006
# Processing miraidon index: 1007
# Processing walkingwake index: 1008
# Processing ironleaves index: 1009
# Processing dipplin index: 1010
# Processing poltchageist index: 1011
# Processing sinistcha index: 1012
# Processing okidogi index: 1013
# Processing munkidori index: 1014
# Processing fezandipiti index: 1015
# Processing ogerpon index: 1016
# Processing archaludon index: 1017
# Processing hydrapple index: 1018
# Processing gougingfire index: 1019
# Processing ragingbolt index: 1020
# Processing ironboulder index: 1021
# Processing iron crown index: 1022
# Processing terapagos index: 1023
# Processing pecharunt index: 1024

# %%
cols = [
    'national_number',
    'gen',
    'english_name',
    'japanese_name',
    'primary_type',
    'secondary_type',
    'classification',
    'percent_male',
    'percent_female',
    'height_m',
    'weight_kg',
    'capture_rate',
    'base_egg_steps',
    'hp',
    'attack',
    'defense',
    'sp_attack',
    'sp_defense',
    'speed'
    ]

for i in range(3):
    cols.append('abilities_{}'.format(i))

cols.append('abilities_hidden')

for i in against.keys():
    cols.append('against_{}'.format(i))

for i in legend.keys():
    cols.append('is_{}'.format(i))

for i in range(7):
    cols.append('evochain_{}'.format(i))

cols.append('description')

# %%
pokedex[cols].to_csv('./data/pokemon_ix.csv', index=False, encoding='utf-8')
