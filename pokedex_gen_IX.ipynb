# %% [markdown]
# # Pokedex
# This notebook is used to collect the full pokedex dataset from Gen IX
# Based on original notebook from https://github.com/cristobalmitchell/pokedex

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# We will use bulbapedia.bulbagarden.net to collect the name of all the pokemon.

# %%
url = "https://bulbapedia.bulbagarden.net/wiki/List_of_Pokémon_by_National_Pokédex_number"

# %%
r = requests.get(url)
soup = BeautifulSoup(r.text, "html.parser")
rows = soup.find_all("tr")

print(len(rows))
# Out:
# 1212

# %%
df = pd.DataFrame()
for row in rows:
    if len(row.find_all("th")) > 1:
        headers = [header.text.replace('\n','').replace(' ','') for header in row.find_all("th")]
    elif len(row.find_all("td")) > 1: 
        record = {}
        for i in range(len(row.find_all("td"))):
            if i < len(headers):
                record[headers[i]] = row.find_all("td")[i].text.replace('\n','').replace(' ','')
        df = pd.concat([df, pd.DataFrame([record])], ignore_index=True)

print(df.head())
# Out:
#     Ndex MS     Pokémon   Type
# 0  #0001      Bulbasaur  Grass
# 1  #0002        Ivysaur  Grass
# 2  #0003       Venusaur  Grass
# 3  #0004     Charmander   Fire
# 4  #0005     Charmeleon   Fire

# %%
cols = ['Ndex', 'Pokémon']
df = df[cols]
df.drop_duplicates(inplace=True)
print(df.head())
# Out:
#     Ndex     Pokémon
# 0  #0001   Bulbasaur
# 1  #0002     Ivysaur
# 2  #0003    Venusaur
# 3  #0004  Charmander
# 4  #0005  Charmeleon

# %%
pokemon_names = df['Pokémon'].to_list()

# %%
pokemon_names = [item.lower() for item in pokemon_names]

# %%
print(pokemon_names[0:5])
# Out:
# ['bulbasaur', 'ivysaur', 'venusaur', 'charmander', 'charmeleon']

# %%
form_name_mapping = {
    'unownoneform': "unown",
    'castformnormal': "castform",
    'deoxysnormalforme': "deoxys",
    'cherrimovercastform': "cherrim",
    'giratinaalteredforme': "giratina",
    'shayminlandforme': "shaymin",
    'basculinred-stripedform': "basculin",
    'deerlingspringform': "deerling",
    'sawsbuckspringform': "sawsbuck",
    'tornadusincarnateforme': "tornadus",
    'thundurusincarnateforme': "thundurus",
    'landorusincarnateforme': "landorus",
    'keldeoordinaryform': "keldeo",
    'meloettaariaforme': "meloetta",
    'furfrounaturalform': "furfrou",
    'aegislashshieldforme': "aegislash",
    'zygarde50%forme': "zygarde",
    'lycanrocmiddayform': "lycanroc",
    'wishiwashisoloform': "wishiwashi",
    'miniormeteorform': "minior",
    'mimikyudisguisedform': "mimikyu",
    'toxtricityampedform': "toxtricity",
    'enamorusincarnateforme': "enamorus",
    'palafinzeroform': "palafin",
    'tatsugiricurlyform': "tatsugiri",
    'dudunsparcetwo-segmentform': "dudunsparce",
    'gimmighoulchestform': "gimmighoul",
    'terapagosnormalform': "terapagos"
}
pokemon_names = [form_name_mapping.get(name, name) for name in pokemon_names]
form_names = [name for name in pokemon_names if "form" in name]
print(form_names)
# Out:
# ['castform']

# %%
# there are some keywords, which now appear in the table with pokemon names. 
# These pokemon have specifier like "fire type" or "red flower" in the name from the table. 
# we need to see this, so we can remove it in the next cell
keywords = [
    "Kyurem", "mode", "rotom", "sea", "cloak", "bre", "flower", "Genesect", "Male", "hoopa",
    "style", "core", "type", "Mane", "wings", "face", "hero", "crown", "rider", "moon",
    "plumage", "mask"
]
keywords = [k.lower() for k in keywords]

matches = {}
for keyword in keywords:
    matches[keyword] = [name for name in pokemon_names if keyword in name]

for keyword, names in matches.items():
    print(f"{keyword}: {names}")
# Out:
# kyurem: ['kyuremkyurem']
# mode: ['darmanitanstandardmode', 'xerneasneutralmode', 'morpekofullbellymode', 'miraidonultimatemode']
# rotom: ['rotomrotom']
# sea: ['horsea', 'seadra', 'seaking', 'sealeo', 'shelloswestsea', 'gastrodonwestsea', 'pansear', 'simisear']
# cloak: ['burmyplantcloak', 'wormadamplantcloak']
# bre: ['umbreon', 'lombre', 'breloom']
# flower: ['flabébéredflower', 'floetteredflower', 'florgesredflower']
# genesect: ['genesectgenesect(nodrive)']
# male: ['meowsticmale', 'indeedeemale', 'basculegionmale', 'oinkolognemale']
# hoopa: ['hoopahoopaconfined']
# style: ['oricoriobailestyle', 'urshifusinglestrikestyle']
# core: []
# type: ['type:null', 'silvallytype:normal']
# mane: ['manectric', 'fluttermane']
# wings: []
# face: ['eiscueiceface']
# hero: ['pheromosa', 'zacianheroofmanybattles', 'zamazentaheroofmanybattles']
# crown: ['ironcrown']
# rider: []
# moon: ['amoonguss', 'roaringmoon']
# plumage: ['squawkabillygreenplumage']
# mask: ['yamask', 'ogerpontealmask']

# %%
category_name_mapping = {
    'kyuremkyurem': 'kyurem',
    'darmanitanstandardmode': 'darmanitan',
    'xerneasneutralmode': 'xerneas',
    'morpekofullbellymode': 'morpeko',
    'miraidonultimatemode': 'miraidon',
    'rotomrotom': 'rotom',
    'shelloswestsea': 'shellos',
    'gastrodonwestsea': 'gastrodon',
    'burmyplantcloak': 'burmy',
    'wormadamplantcloak': 'wormadam',
    'flabébéredflower': 'flabébé',
    'floetteredflower': 'floette',
    'florgesredflower': 'florges',
    'genesectgenesect(nodrive)': 'genesect',
    'meowsticmale': 'meowstic',
    'indeedeemale': 'indeedee',
    'basculegionmale': 'basculegion',
    'oinkolognemale': 'oinkologne',
    'hoopahoopaconfined': 'hoopa',
    'mausholdfamilyofthree': 'maushold',
    'koraidonapexbuild': 'koraidon',
    'oricoriobailestyle': 'oricorio',
    'urshifusinglestrikestyle': 'urshifu',
    'type:null': 'type:null',
    'silvallytype:normal': 'silvally',
    'fluttermane': 'flutter mane',
    'eiscueiceface': 'eiscue',
    'zacianheroofmanybattles': 'zacian',
    'zamazentaheroofmanybattles': 'zamazenta',
    'ironcrown': 'iron crown',
    'roaringmoon': 'roaring moon',
    'squawkabillygreenplumage': 'squawkabilly',
    'ogerpontealmask': 'ogerpon',
    'kyogrekyogre': 'kyogre',
    'groudongroudon': 'groudon',
    'alcremievanillacream': 'alcremie',
}

pokemon_names = [category_name_mapping.get(name, name) for name in pokemon_names]

# %% [markdown]
# Now we will use the primary data source of Serebii.net using their Gen IX pokedex

# %%
url = "https://www.serebii.net/pokedex-sv/{}/#stats"

# %%
def get_number(soup):
    tables = soup.find_all("table", class_="dextable")
    if len(tables) < 2:
        return None
    table = tables[1]
    try:
        num = table.find_all("tr")[1].find_all("td", class_="fooinfo")[2].text.strip().split('\n')[0].split("#")[-1]
        return num
    except Exception:
        return None

# %%
def get_name(soup):
    table = soup.find_all("table", class_="dextable")[1]
    name = table.find_all("tr")[1].find_all("td")[0].text
    
    return name

# %%
def get_altnames(soup):
    altnames = {}
    table = soup.find_all("table", class_="dextable")[1]
    rows = table.find_all("tr")[1].find_all("td")[1].find_all("tr")
    for row in rows:
        key = row.find_all("td")[0].text.strip().replace(":","")
        contents = row.find_all("td")[1].contents
        value = [x for x in contents if isinstance(x, type(contents[0]))]
        altnames[key] = value
    
    return altnames

# %%
def get_type(soup):
    types = []
    table = soup.find_all("table", class_="dextable")[1]
    imgs = table.find_all("img")
    for img in imgs:
        types.append(img["src"].split("/")[-1].split(".")[0])
    
    return types

# %%
def get_gender(soup):
    gender_ratios = {}
    table = soup.find_all("table", class_="dextable")[1]
    try:  #genderless pokemon will cause exception
        rows = table.find_all("tr")[1].find_all("td", class_="fooinfo")[3].contents[0].find_all("tr")
        for row in rows:
            key = row.find_all("td")[0].text.split(" ")[0]
            value = row.find_all("td")[1].text
            gender_ratios[key] = value
    except:
        pass

    return gender_ratios

# %%
def get_classification(soup):
    table = soup.find_all("table", class_="dextable")[1]
    classification = table.find_all("td", class_="fooinfo")[4].text
    
    return classification

# %%
def get_height(soup):
    table = soup.find_all("table", class_="dextable")[1]
    height = table.find_all("td", class_="fooinfo")[5].text.split("\t")[-1]
    
    return height

# %%
def get_weight(soup):
    table = soup.find_all("table", class_="dextable")[1]
    weight = table.find_all("td", class_="fooinfo")[6].text.split("\t")[-1]
    
    return weight

# %%
def get_capture_rate(soup):
    table = soup.find_all("table", class_="dextable")[1]
    rate = table.find_all("td", class_="fooinfo")[7].text.split("\t")[-1]
    
    return rate

# %%
def get_base_egg_steps(soup):
    table = soup.find_all("table", class_="dextable")[1]
    steps = table.find_all("td", class_="fooinfo")[8].text.split("\t")[-1].replace(",","")
    
    return steps

# %%
def get_base_stats(soup):
    base_stats = {}
    stat_names = ["HP","Attack","Defense","Sp. Attack","Sp. Defense","Speed"]

    stats_indices = []
    for row in soup.find_all("tr"):
        if 'Stats' == row.text.replace('\n',''):
            stats_indices.append(soup.find_all("tr").index(row))

    try:
        columns = soup.find_all("tr")[stats_indices[0]+2].find_all("td")

    except:
        columns = soup.find_all("tr")[stats_indices[1]+2].find_all("td")

    for i in range(len(stat_names)):
        base_stats[stat_names[i]] = columns[i+1].text

    return base_stats

# %%
def get_legendary_status(name):
                
    legendary_status = {"sublegendary": 0, "legendary": 0, "mythical": 0}
    if name in status_dict["sublegendary"]:
        legendary_status["sublegendary"] = 1
    elif name in status_dict["legendary"]:
        legendary_status["legendary"] = 1
    elif name in status_dict["mythical"]:
        legendary_status["mythical"] = 1
    
    return legendary_status

# %%
def get_experience_growth(soup):
    table = soup.find_all("table", class_="dextable")[2].find_all("tr", recursive=False)[3]
    exp = table.find_all("tr", recursive=False)[3].td.contents[0].split(" ")[0].replace(",","")
    
    return exp

# %%
def get_base_happiness(soup):
    table = soup.find_all("table", class_="dextable")[2].find_all("tr", recursive=False)[3]
    happiness = table.find_all("tr", recursive=False)[3].find_all("td",recursive=False)[1].text
    
    return happiness

# %%
def get_against(soup):
    headers = []
    against_dict = {}
    links = soup.find_all("table", class_="dextable")[3].find_all("tr",recursive=False)[1].find_all("a")
    for link in links:
        header = link['href'].split("/")[-1].split(".")[0]
        headers.append(header)
    
    columns = soup.find_all("table", class_="dextable")[3].find_all("tr",recursive=False)[2].find_all('td')
    for i in range(len(headers)):
        against_dict[headers[i]] = columns[i].text.split('*')[-1]
    
    return against_dict

# %%
def get_abilities(soup):
    table = soup.find_all("table", class_="dextable")[2]
    abilities = table.find_all('tr')[0].text.split(": ")[1].strip().split(" - ")
    
    return abilities

# %%
def get_gen(number):
    if int(number) <= 151:
        gen = 'I'
    elif int(number) <= 251:
        gen = 'II'
    elif int(number) <= 386:
        gen = 'III'
    elif int(number) <= 493:
        gen = 'IV'
    elif int(number) <= 649:
        gen = 'V'
    elif int(number) <= 721:
        gen = 'VI'
    elif int(number) <= 809:
        gen = 'VII'
    elif int(number) <= 905:
        gen = 'VIII'
    elif int(number) <= 1025:
        gen = 'IX'
    else:
        gen = 'X'
    
    return gen

# %%
def get_description(name):
    name = name.replace("'",'').replace(' ','-').replace('.',' ').strip().replace(' ','-').replace(':','-')
    if name == 'nidoran♀':
        name = 'nidoran-female'
    elif name == 'nidoran♂':
        name = 'nidoran-male'
    elif name == 'mimejr':
        name = 'mime-jr'
    elif name[:4] == 'tapu':
        name = name[:4] + '-' + name[4:]
    elif name == 'type:null':
        name = 'type-null'
    elif name == 'flutter mane':
        name = 'flutter-mane'
    elif name == 'iron crown':
        name = 'iron-crown'
    elif name =="roaring moon":
        name = "roaring-moon"
    try:
        url = 'https://www.pokemon.com/us/pokedex/{}'
        r = requests.get(url.format(name))
        soup = BeautifulSoup(r.text, "html.parser")
        desc = soup.find('div', class_='version-descriptions active').find('p', class_='active').contents[0].strip()
    except:
        desc = ''

    return desc

# %%
def get_evochain(soup):
    table = soup.find_all("table", class_="evochain")[0]
    chain = []
    if len(table.find_all('tr')) == 1:
        for img in table.find_all('img'):
            try:
                a = img['title']
                chain.append(a)   
            except:
                try:
                    a = img['alt']
                    chain.append(a) 
                except:
                    pass
    
    elif table.find('a')['href'].split('/')[1] == 'pokedex-sv':
        row = table.find('tr')
        for col in row.find_all('td')[:7]:
            try:
                a = col.find('img')['title'].strip()
            except:
                try:
                    a = col.find('img')['alt'].strip()
                except:
                    number = col.find('a')['href'].split('/')[-1].split('.')[0]
                    a = pokemon_names[int(number)-1].capitalize()
            chain.append(a)
    
    else:
        for col in table.find_all('td')[:7]:
            try:
                a = col.find('img')['title'].strip()
            except:
                try:
                    a = col.find('img')['alt'].strip()
                except:
                    try:
                        number = col.find('img')['src'].split('/')[-1].split('.')[0]
                        a = pokemon_names[int(number)-1].capitalize()
                    except:
                        pass
                    #a = col.find('a')['href'].split('/')[-1].capitalize()
            chain.append(a)
    
    if len(chain)>1:
        if chain[0] == chain[1]:
            chain.pop(0)
    
        if len(chain)>3 and chain[2] == chain[3]:
            try:
                chain.pop(5)
            except:
                pass
            chain.pop(4)
            chain.pop(3)

        try:
            if chain[4] == chain[5]:
                chain.pop(6)
                chain.pop(5)
        except:
            pass 
    
    return chain

# %%
pokedex = pd.DataFrame()
url = "https://www.serebii.net/pokemon/legendary.shtml"
r = requests.get(url)
soup = BeautifulSoup(r.text, "html.parser")
tables = soup.find_all("table", class_="trainer")
status_list = ["sublegendary","legendary","mythical"]
status_dict = {}
for i in range(len(tables)):
    status_dict[status_list[i]] = []
    for row in tables[i].find_all("tr", recursive=False)[1:-1]:
        for column in row.find_all("td", recursive=False):
            item = column.find_all('td')[1].text
            status_dict[status_list[i]].append(item)
            
for index, pokemon in enumerate(pokemon_names):
    if index < 800:
        continue
    print("Processing {}".format(pokemon)   )
    stats = {}


    pokemon_search = pokemon.replace(" ", "")
    
    try:
        url = "https://www.serebii.net/pokedex-sv/{}/#stats"
        r = requests.get(url.format(pokemon_search))
        soup = BeautifulSoup(r.text, "html.parser")
        check = soup.find_all("table", class_="dextable")[1]
    except:
        url = "https://www.serebii.net/pokedex-swsh/{}.shtml"
        number = "{0:0=3d}".format(pokemon_names.index(pokemon_search)+1)
        r = requests.get(url.format(number))
        soup = BeautifulSoup(r.text, "html.parser")
    
    stats['national_number'] = get_number(soup)
    if stats['national_number'] is None:
        print("Skipping {}, no national number found.".format(pokemon))
        continue
    
    stats['gen'] = get_gen(stats['national_number'])
    if stats['gen'] != "IX":
        print("Skipping {}, not Gen IX.".format(pokemon))
        continue
    stats['english_name'] = get_name(soup)
    stats['japanese_name'] = get_altnames(soup)['Japan'][0]
    stats['primary_type'] = get_type(soup)[0]
    stats['secondary_type'] = get_type(soup)[1] if len(get_type(soup))>1 else None 
    stats['percent_male'] = get_gender(soup)['Male'].replace('%','') if len(get_gender(soup))>1 else None
    stats['percent_female'] = get_gender(soup)['Female'].replace('%','') if len(get_gender(soup))>1 else None
    stats['classification'] = get_classification(soup)
    stats['height_m'] = get_height(soup).split('m')[0]
    stats['weight_kg'] = get_weight(soup).split('kg')[0]
    stats['capture_rate'] = get_capture_rate(soup)
    stats['base_egg_steps'] = get_base_egg_steps(soup)
    stats['hp'] = get_base_stats(soup)["HP"]
    stats['attack'] = get_base_stats(soup)["Attack"]
    stats['defense'] = get_base_stats(soup)["Defense"]
    stats['sp_attack'] = get_base_stats(soup)["Sp. Attack"]
    stats['sp_defense'] = get_base_stats(soup)["Sp. Defense"]
    stats['speed'] = get_base_stats(soup)["Speed"]
    stats['description'] = get_description(pokemon)
    
    abilities = get_abilities(soup)
    for i in range(3):
        try:
            if 'Hidden' not in abilities[i]:
                stats['abilities_{}'.format(i)] = abilities[i]
            elif 'Hidden' in abilities[i]:
                stats['abilities_hidden'] = abilities[i].split('(')[0].strip()
        except:
             stats['abilities_{}'.format(i)] = None
                
    for i in range(7):
        try:
            stats['evochain_{}'.format(i)] = get_evochain(soup)[i]
        except:
            stats['evochain_{}'.format(i)] = None
    
    legend = get_legendary_status(stats['english_name'])
    for i in legend.keys():
        stats['is_{}'.format(i)] = legend[i]
    
    against = get_against(soup)
    for i in against.keys():
        stats['against_{}'.format(i)] = against[i]
    pokedex = pd.concat([pokedex, pd.DataFrame([stats])], ignore_index=True)
# Out:
# Processing hakamo-o
# Skipping hakamo-o, not Gen IX.
# Processing kommo-o
# Skipping kommo-o, not Gen IX.
# Processing tapukoko
# Skipping tapukoko, not Gen IX.
# Processing tapulele
# Skipping tapulele, not Gen IX.
# Processing tapubulu
# Skipping tapubulu, not Gen IX.
# Processing tapufini
# Skipping tapufini, not Gen IX.
# Processing cosmog
# Skipping cosmog, not Gen IX.
# Processing cosmoem
# Skipping cosmoem, not Gen IX.
# Processing solgaleo
# Skipping solgaleo, not Gen IX.
# Processing lunala
# Skipping lunala, not Gen IX.
# Processing nihilego
# Skipping nihilego, not Gen IX.
# Processing buzzwole
# Skipping buzzwole, not Gen IX.
# Processing pheromosa
# Skipping pheromosa, not Gen IX.
# Processing xurkitree
# Skipping xurkitree, not Gen IX.
# Processing celesteela
# Skipping celesteela, not Gen IX.
# Processing kartana
# Skipping kartana, not Gen IX.
# Processing guzzlord
# Skipping guzzlord, not Gen IX.
# Processing necrozma
# Skipping necrozma, not Gen IX.
# Processing magearna
# Skipping magearna, not Gen IX.
# Processing marshadow
# Skipping marshadow, not Gen IX.
# Processing poipole
# Skipping poipole, not Gen IX.
# Processing naganadel
# Skipping naganadel, not Gen IX.
# Processing stakataka
# Skipping stakataka, not Gen IX.
# Processing blacephalon
# Skipping blacephalon, not Gen IX.
# Processing zeraora
# Skipping zeraora, not Gen IX.
# Processing meltan
# Skipping meltan, not Gen IX.
# Processing melmetal
# Skipping melmetal, not Gen IX.
# Processing grookey
# Skipping grookey, not Gen IX.
# Processing thwackey
# Skipping thwackey, not Gen IX.
# Processing rillaboom
# Skipping rillaboom, not Gen IX.
# Processing scorbunny
# Skipping scorbunny, not Gen IX.
# Processing raboot
# Skipping raboot, not Gen IX.
# Processing cinderace
# Skipping cinderace, not Gen IX.
# Processing sobble
# Skipping sobble, not Gen IX.
# Processing drizzile
# Skipping drizzile, not Gen IX.
# Processing inteleon
# Skipping inteleon, not Gen IX.
# Processing skwovet
# Skipping skwovet, not Gen IX.
# Processing greedent
# Skipping greedent, not Gen IX.
# Processing rookidee
# Skipping rookidee, not Gen IX.
# Processing corvisquire
# Skipping corvisquire, not Gen IX.
# Processing corviknight
# Skipping corviknight, not Gen IX.
# Processing blipbug
# Skipping blipbug, not Gen IX.
# Processing dottler
# Skipping dottler, not Gen IX.
# Processing orbeetle
# Skipping orbeetle, not Gen IX.
# Processing nickit
# Skipping nickit, not Gen IX.
# Processing thievul
# Skipping thievul, not Gen IX.
# Processing gossifleur
# Skipping gossifleur, not Gen IX.
# Processing eldegoss
# Skipping eldegoss, not Gen IX.
# Processing wooloo
# Skipping wooloo, not Gen IX.
# Processing dubwool
# Skipping dubwool, not Gen IX.
# Processing chewtle
# Skipping chewtle, not Gen IX.
# Processing drednaw
# Skipping drednaw, not Gen IX.
# Processing yamper
# Skipping yamper, not Gen IX.
# Processing boltund
# Skipping boltund, not Gen IX.
# Processing rolycoly
# Skipping rolycoly, not Gen IX.
# Processing carkol
# Skipping carkol, not Gen IX.
# Processing coalossal
# Skipping coalossal, not Gen IX.
# Processing applin
# Skipping applin, not Gen IX.
# Processing flapple
# Skipping flapple, not Gen IX.
# Processing appletun
# Skipping appletun, not Gen IX.
# Processing silicobra
# Skipping silicobra, not Gen IX.
# Processing sandaconda
# Skipping sandaconda, not Gen IX.
# Processing cramorant
# Skipping cramorant, not Gen IX.
# Processing arrokuda
# Skipping arrokuda, not Gen IX.
# Processing barraskewda
# Skipping barraskewda, not Gen IX.
# Processing toxel
# Skipping toxel, not Gen IX.
# Processing toxtricity
# Skipping toxtricity, not Gen IX.
# Processing sizzlipede
# Skipping sizzlipede, not Gen IX.
# Processing centiskorch
# Skipping centiskorch, not Gen IX.
# Processing clobbopus
# Skipping clobbopus, not Gen IX.
# Processing grapploct
# Skipping grapploct, not Gen IX.
# Processing sinistea
# Skipping sinistea, not Gen IX.
# Processing polteageist
# Skipping polteageist, not Gen IX.
# Processing hatenna
# Skipping hatenna, not Gen IX.
# Processing hattrem
# Skipping hattrem, not Gen IX.
# Processing hatterene
# Skipping hatterene, not Gen IX.
# Processing impidimp
# Skipping impidimp, not Gen IX.
# Processing morgrem
# Skipping morgrem, not Gen IX.
# Processing grimmsnarl
# Skipping grimmsnarl, not Gen IX.
# Processing obstagoon
# Skipping obstagoon, not Gen IX.
# Processing perrserker
# Skipping perrserker, not Gen IX.
# Processing cursola
# Skipping cursola, not Gen IX.
# Processing sirfetch'd
# Skipping sirfetch'd, not Gen IX.
# Processing mr.rime
# Skipping mr.rime, not Gen IX.
# Processing runerigus
# Skipping runerigus, not Gen IX.
# Processing milcery
# Skipping milcery, not Gen IX.
# Processing alcremievanillacream
# Skipping alcremievanillacream, not Gen IX.
# Processing falinks
# Skipping falinks, not Gen IX.
# Processing pincurchin
# Skipping pincurchin, not Gen IX.
# Processing snom
# Skipping snom, not Gen IX.
# Processing frosmoth
# Skipping frosmoth, not Gen IX.
# Processing stonjourner
# Skipping stonjourner, not Gen IX.
# Processing eiscue
# Skipping eiscue, not Gen IX.
# Processing indeedee
# Skipping indeedee, not Gen IX.
# Processing morpeko
# Skipping morpeko, not Gen IX.
# Processing cufant
# Skipping cufant, not Gen IX.
# Processing copperajah
# Skipping copperajah, not Gen IX.
# Processing dracozolt
# Skipping dracozolt, not Gen IX.
# Processing arctozolt
# Skipping arctozolt, not Gen IX.
# Processing dracovish
# Skipping dracovish, not Gen IX.
# Processing arctovish
# Skipping arctovish, not Gen IX.
# Processing duraludon
# Skipping duraludon, not Gen IX.
# Processing dreepy
# Skipping dreepy, not Gen IX.
# Processing drakloak
# Skipping drakloak, not Gen IX.
# Processing dragapult
# Skipping dragapult, not Gen IX.
# Processing zacian
# Skipping zacian, not Gen IX.
# Processing zamazenta
# Skipping zamazenta, not Gen IX.
# Processing eternatus
# Skipping eternatus, not Gen IX.
# Processing kubfu
# Skipping kubfu, not Gen IX.
# Processing urshifu
# Skipping urshifu, not Gen IX.
# Processing zarude
# Skipping zarude, not Gen IX.
# Processing regieleki
# Skipping regieleki, not Gen IX.
# Processing regidrago
# Skipping regidrago, not Gen IX.
# Processing glastrier
# Skipping glastrier, not Gen IX.
# Processing spectrier
# Skipping spectrier, not Gen IX.
# Processing calyrex
# Skipping calyrex, not Gen IX.
# Processing wyrdeer
# Skipping wyrdeer, not Gen IX.
# Processing kleavor
# Skipping kleavor, not Gen IX.
# Processing ursaluna
# Skipping ursaluna, not Gen IX.
# Processing basculegion
# Skipping basculegion, not Gen IX.
# Processing sneasler
# Skipping sneasler, not Gen IX.
# Processing overqwil
# Skipping overqwil, not Gen IX.
# Processing enamorus
# Skipping enamorus, not Gen IX.
# Processing sprigatito
# Processing floragato
# Processing meowscarada
# Processing fuecoco
# Processing crocalor
# Processing skeledirge
# Processing quaxly
# Processing quaxwell
# Processing quaquaval
# Processing lechonk
# Processing oinkologne
# Processing tarountula
# Processing spidops
# Processing nymble
# Processing lokix
# Processing pawmi
# Processing pawmo
# Processing pawmot
# Processing tandemaus
# Processing maushold
# Processing fidough
# Processing dachsbun
# Processing smoliv
# Processing dolliv
# Processing arboliva
# Processing squawkabilly
# Processing nacli
# Processing naclstack
# Processing garganacl
# Processing charcadet
# Processing armarouge
# Processing ceruledge
# Processing tadbulb
# Processing bellibolt
# Processing wattrel
# Processing kilowattrel
# Processing maschiff
# Processing mabosstiff
# Processing shroodle
# Processing grafaiai
# Processing bramblin
# Processing brambleghast
# Processing toedscool
# Processing toedscruel
# Processing klawf
# Processing capsakid
# Processing scovillain
# Processing rellor
# Processing rabsca
# Processing flittle
# Processing espathra
# Processing tinkatink
# Processing tinkatuff
# Processing tinkaton
# Processing wiglett
# Processing wugtrio
# Processing bombirdier
# Processing finizen
# Processing palafin
# Processing varoom
# Processing revavroom
# Processing cyclizar
# Processing orthworm
# Processing glimmet
# Processing glimmora
# Processing greavard
# Processing houndstone
# Processing flamigo
# Processing cetoddle
# Processing cetitan
# Processing veluza
# Processing dondozo
# Processing tatsugiri
# Processing annihilape
# Processing clodsire
# Processing farigiraf
# Processing dudunsparce
# Processing kingambit
# Processing greattusk
# Processing screamtail
# Processing brutebonnet
# Processing flutter mane
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 28
#      27     soup = BeautifulSoup(r.text, "html.parser")
# ---> 28     check = soup.find_all("table", class_="dextable")[1]
#      29 except:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 31
#      29 except:
#      30     url = "https://www.serebii.net/pokedex-swsh/{}.shtml"
# ---> 31     number = "{0:0=3d}".format(pokemon_names.index(pokemon_search)+1)
#      32     r = requests.get(url.format(number))
#      33     soup = BeautifulSoup(r.text, "html.parser")
#
# ValueError: 'flutter_mane' is not in list

# %%
cols = [
    'national_number',
    'gen',
    'english_name',
    'japanese_name',
    'primary_type',
    'secondary_type',
    'classification',
    'percent_male',
    'percent_female',
    'height_m',
    'weight_kg',
    'capture_rate',
    'base_egg_steps',
    'hp',
    'attack',
    'defense',
    'sp_attack',
    'sp_defense',
    'speed'
    ]

for i in range(3):
    cols.append('abilities_{}'.format(i))

cols.append('abilities_hidden')

for i in against.keys():
    cols.append('against_{}'.format(i))

for i in legend.keys():
    cols.append('is_{}'.format(i))

for i in range(7):
    cols.append('evochain_{}'.format(i))

cols.append('description')

# %%
pokedex[cols].to_csv('./data/pokemon_ix.csv', index=False, encoding='utf-8')
